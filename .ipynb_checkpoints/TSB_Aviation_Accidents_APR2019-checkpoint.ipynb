# %% [markdown]
# ### Read and explore the different datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quilt
import seaborn as sns
import missingno as msno
import plotly.offline
import plotly_express as px

#import geopandas as gp

# %%
#pip install cufflinks

# %%
#pip install plotly_express

# %%
# import cufflinks
# cufflinks.__version__

# %%
#pip install cufflinks --upgrade

# %%
#pip install python-quilt

# %%
#Read datasets, no description available. ALl files available at http://www.tsb.gc.ca/eng/stats/aviation/data-5.html
df1 = pd.read_csv('ASISdb_MDOTW_VW_OCCURRENCE_PUBLIC.csv')
df2 = pd.read_csv('ASISdb_MDOTW_VW_AIRCRAFT_PUBLIC.csv')
#df3 = pd.read_csv('ASISdb_MDOTW_VW_EVENTS_AND_PHASES_PUBLIC.csv')
#df4 = pd.read_csv('ASISdb_MDOTW_VW_EVENTS_AND_PHASES_PUBLIC.csv')

# %%
df1.head()
# Out:
#     OccID     OccNo  AirportID AirportID_AirportName  AirportID_CountryID  \
# 0  152828  A19P0071     1984.0     Erik Nielsen Intl                  2.0
# 1  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 2  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 3  152826  A19P0070      109.0     (CAMPBELL ISLAND)                  2.0
# 4  152825  A19P0069     1912.0        Vancouver Intl                  2.0
#
#   AirportID_CountryID_DisplayEng AirportID_CountryID_DisplayFre  \
# 0                         CANADA                         CANADA
# 1                         CANADA                         CANADA
# 2                         CANADA                         CANADA
# 3                         CANADA                         CANADA
# 4                         CANADA                         CANADA
#
#    Airport_ProvinceID AirportID_ProvinceID_DisplayEng  \
# 0                24.0                           YUKON
# 1                24.0                           YUKON
# 2                24.0                           YUKON
# 3                12.0                BRITISH COLUMBIA
# 4                12.0                BRITISH COLUMBIA
#
#   AirportID_ProvinceID_DisplayFre  ... InitialPositionEnum_DisplayFre  \
# 0                           YUKON  ...                            NaN
# 1                           YUKON  ...                            NaN
# 2                           YUKON  ...                            NaN
# 3            COLOMBIE-BRITANNIQUE  ...                            NaN
# 4            COLOMBIE-BRITANNIQUE  ...                            NaN
#
#    FinalPositionEnum  FinalPositionEnum_DisplayEng  \
# 0                NaN                           NaN
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4                NaN                           NaN
#
#   FinalPositionEnum_DisplayFre FullProcedureIND  FullProcedureIND_DisplayEng  \
# 0                          NaN              NaN                          NaN
# 1                          NaN              NaN                          NaN
# 2                          NaN              NaN                          NaN
# 3                          NaN              NaN                          NaN
# 4                          NaN              NaN                          NaN
#
#    FullProcedureIND_DisplayFre SurfaceContaminationID  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
#
#   SurfaceContaminationID_DisplayEng SurfaceContaminationID_DisplayFre
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 246 columns]

# %%
#Rename occid

df2 = df2.rename(index=str, columns={"occid": "OccID"})

# %%
df2.shape
# Out:
# (57227, 194)

# %%
#df2[df2.columns[df2.isnull().mean()< 0.4]]

# %%
#pip install missingno

# %%
df2.head()
# Out:
#     OccID     OccNo   AcID  AircraftID  AircraftVersion  RowStatus  \
# 0  152828  A19P0071  43955      106710              9.0          1
# 1  152827  A19W0070  67261      131335              2.0          1
# 2  152826  A19P0070  67259      131334              2.0          1
# 3  152825  A19P0069  65985      130580              2.0          1
# 4  152822  A19C0063  43825      106425              2.0          1
#
#   RegistrationNo SerialNo  AircraftTypeID AircraftTypeID_DisplayEng  ...  \
# 0         C-GJAZ    15036             1.0                 AEROPLANE  ...
# 1         C-FANF    27417             1.0                 AEROPLANE  ...
# 2         C-FQNG    61032             3.0                HELICOPTER  ...
# 3         N403UA      442             1.0                 AEROPLANE  ...
# 4         C-FARE    53112             3.0                HELICOPTER  ...
#
#   ReqSepTime  ActualSepHorizontal ActualSepHorizontalEnum  \
# 0        NaN                  NaN                     NaN
# 1        NaN                  NaN                     NaN
# 2        NaN                  NaN                     NaN
# 3        NaN                  NaN                     NaN
# 4        NaN                  NaN                     NaN
#
#   ActualSepHorizontalEnum_DisplayEng  ActualSepHorizontalEnum_DisplayFre  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   ActualSepVertical ActualSepTime AtsUnitInvolvedEnum  \
# 0               NaN           NaN                 NaN
# 1               NaN           NaN                 NaN
# 2               NaN           NaN                 NaN
# 3               NaN           NaN                 NaN
# 4               NaN           NaN                 NaN
#
#    AtsUnitInvolvedEnum_DisplayEng AtsUnitInvolvedEnum_DisplayFre
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
# [5 rows x 194 columns]

# %%
df2.columns
# Out:
# Index(['OccID', 'OccNo', 'AcID', 'AircraftID', 'AircraftVersion', 'RowStatus',
#        'RegistrationNo', 'SerialNo', 'AircraftTypeID',
#        'AircraftTypeID_DisplayEng',
#        ...
#        'ReqSepTime', 'ActualSepHorizontal', 'ActualSepHorizontalEnum',
#        'ActualSepHorizontalEnum_DisplayEng',
#        'ActualSepHorizontalEnum_DisplayFre', 'ActualSepVertical',
#        'ActualSepTime', 'AtsUnitInvolvedEnum',
#        'AtsUnitInvolvedEnum_DisplayEng', 'AtsUnitInvolvedEnum_DisplayFre'],
#       dtype='object', length=194)

# %%
df2u = df2.OccID.nunique()
print (df2u)
# Out:
# 43854

# %%
# df1_.reset_index().drop_duplicates().set_index(['OccId']) Doesn't work!

# %%
df1.shape
# Out:
# (47226, 246)

# %%
df1.head()
# Out:
#     OccID     OccNo  AirportID AirportID_AirportName  AirportID_CountryID  \
# 0  152828  A19P0071     1984.0     Erik Nielsen Intl                  2.0
# 1  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 2  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 3  152826  A19P0070      109.0     (CAMPBELL ISLAND)                  2.0
# 4  152825  A19P0069     1912.0        Vancouver Intl                  2.0
#
#   AirportID_CountryID_DisplayEng AirportID_CountryID_DisplayFre  \
# 0                         CANADA                         CANADA
# 1                         CANADA                         CANADA
# 2                         CANADA                         CANADA
# 3                         CANADA                         CANADA
# 4                         CANADA                         CANADA
#
#    Airport_ProvinceID AirportID_ProvinceID_DisplayEng  \
# 0                24.0                           YUKON
# 1                24.0                           YUKON
# 2                24.0                           YUKON
# 3                12.0                BRITISH COLUMBIA
# 4                12.0                BRITISH COLUMBIA
#
#   AirportID_ProvinceID_DisplayFre  ... InitialPositionEnum_DisplayFre  \
# 0                           YUKON  ...                            NaN
# 1                           YUKON  ...                            NaN
# 2                           YUKON  ...                            NaN
# 3            COLOMBIE-BRITANNIQUE  ...                            NaN
# 4            COLOMBIE-BRITANNIQUE  ...                            NaN
#
#    FinalPositionEnum  FinalPositionEnum_DisplayEng  \
# 0                NaN                           NaN
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4                NaN                           NaN
#
#   FinalPositionEnum_DisplayFre FullProcedureIND  FullProcedureIND_DisplayEng  \
# 0                          NaN              NaN                          NaN
# 1                          NaN              NaN                          NaN
# 2                          NaN              NaN                          NaN
# 3                          NaN              NaN                          NaN
# 4                          NaN              NaN                          NaN
#
#    FullProcedureIND_DisplayFre SurfaceContaminationID  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
#
#   SurfaceContaminationID_DisplayEng SurfaceContaminationID_DisplayFre
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
# [5 rows x 246 columns]

# %%
df1.columns
# Out:
# Index(['OccID', 'OccNo', 'AirportID', 'AirportID_AirportName',
#        'AirportID_CountryID', 'AirportID_CountryID_DisplayEng',
#        'AirportID_CountryID_DisplayFre', 'Airport_ProvinceID',
#        'AirportID_ProvinceID_DisplayEng', 'AirportID_ProvinceID_DisplayFre',
#        ...
#        'InitialPositionEnum_DisplayFre', 'FinalPositionEnum',
#        'FinalPositionEnum_DisplayEng', 'FinalPositionEnum_DisplayFre',
#        'FullProcedureIND', 'FullProcedureIND_DisplayEng',
#        'FullProcedureIND_DisplayFre', 'SurfaceContaminationID',
#        'SurfaceContaminationID_DisplayEng',
#        'SurfaceContaminationID_DisplayFre'],
#       dtype='object', length=246)

# %%
df1u = df1.OccID.nunique()

# %%
#df3.head()

# %%
#df3.shape

# %%
#df3u = df3.OccID.nunique()

# %%
#df4.head()

# %%
#df4.shape

# %%
#df4u = df4.OccID.nunique()

# %%
unique_ = pd.DataFrame({'Dataset' :["AC","EVE"],#"OCC","SUR"], 
                        "Unique":[df1u,df2u]})#df3u,df4u
unique_.sort_values(by="Unique", ascending=False)
# Out:
#   Dataset  Unique
# 0      AC   43855
# 1     EVE   43854

# %% [markdown]
# #### One feature seems common and can be used as keys, merge all datasets into one

# %%
#dfs = [df.set_index(['OccID']) for df in [df1, df2]]

# dfc_ = reduce(lambda left, right: pd.merge((left,right, on=['OccID'], how='outer', indicator=True)
#      .query('_merge != "both"')
#      .drop('_merge', 1),  dfs)

# (left.merge(right, on='key', how='outer', indicator=True)
#      .query('_merge != "both"')
#      .drop('_merge', 1))

# %%
df = df1.merge(df2, how='left', left_on=('OccID','OccNo'), right_on=('OccID','OccNo'))

# %%
#dfm.TotalFatalCount

# %%
# from functools import reduce
# dfm = reduce(lambda left,right: pd.merge(left,right, on='OccID',how='inner'), dfs)

# %%
df.shape
# Out:
# (68258, 438)

# %%
df.head()
# Out:
#     OccID     OccNo  AirportID AirportID_AirportName  AirportID_CountryID  \
# 0  152828  A19P0071     1984.0     Erik Nielsen Intl                  2.0
# 1  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 2  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 3  152826  A19P0070      109.0     (CAMPBELL ISLAND)                  2.0
# 4  152825  A19P0069     1912.0        Vancouver Intl                  2.0
#
#   AirportID_CountryID_DisplayEng AirportID_CountryID_DisplayFre  \
# 0                         CANADA                         CANADA
# 1                         CANADA                         CANADA
# 2                         CANADA                         CANADA
# 3                         CANADA                         CANADA
# 4                         CANADA                         CANADA
#
#    Airport_ProvinceID AirportID_ProvinceID_DisplayEng  \
# 0                24.0                           YUKON
# 1                24.0                           YUKON
# 2                24.0                           YUKON
# 3                12.0                BRITISH COLUMBIA
# 4                12.0                BRITISH COLUMBIA
#
#   AirportID_ProvinceID_DisplayFre  ... ReqSepTime  ActualSepHorizontal  \
# 0                           YUKON  ...        NaN                  NaN
# 1                           YUKON  ...        NaN                  NaN
# 2                           YUKON  ...        NaN                  NaN
# 3            COLOMBIE-BRITANNIQUE  ...        NaN                  NaN
# 4            COLOMBIE-BRITANNIQUE  ...        NaN                  NaN
#
#    ActualSepHorizontalEnum ActualSepHorizontalEnum_DisplayEng  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#   ActualSepHorizontalEnum_DisplayFre  ActualSepVertical  ActualSepTime  \
# 0                                NaN                NaN            NaN
# 1                                NaN                NaN            NaN
# 2                                NaN                NaN            NaN
# 3                                NaN                NaN            NaN
# 4                                NaN                NaN            NaN
#
#   AtsUnitInvolvedEnum AtsUnitInvolvedEnum_DisplayEng  \
# 0                 NaN                            NaN
# 1                 NaN                            NaN
# 2                 NaN                            NaN
# 3                 NaN                            NaN
# 4                 NaN                            NaN
#
#   AtsUnitInvolvedEnum_DisplayFre
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 438 columns]

# %%
#Select relevant features, USE df=df[]!!!!
df = df[['OccID', 'OccNo', 'RegistrationNo', 'AircraftTypeID_DisplayEng', 'AircraftModelID_DisplayEng', 
      'AircraftMakeID_DisplayEng','OrganizationID_DisplayEng', 'OperatorTypeID_DisplayEng',
      'YearOfManuf','NumberOfEngine','OperationTypeID_DisplayEng','Latitude','Longitude', 
      'OccDate', 'OccTime', 'OccTypeID_DisplayEng', 'TotalFatalCount']]
df.head()
# Out:
#     OccID     OccNo RegistrationNo AircraftTypeID_DisplayEng  \
# 0  152828  A19P0071         C-GJAZ                 AEROPLANE
# 1  152827  A19W0070         C-FANF                 AEROPLANE
# 2  152827  A19W0070         C-FANF                 AEROPLANE
# 3  152826  A19P0070         C-FQNG                HELICOPTER
# 4  152825  A19P0069         N403UA                 AEROPLANE
#
#   AircraftModelID_DisplayEng AircraftMakeID_DisplayEng  \
# 0      CL-600-2D24 (CRJ 900)                BOMBARDIER
# 1                    737-500                    BOEING
# 2                    737-500                    BOEING
# 3                      S-61N                  SIKORSKY
# 4                   A320-200                    AIRBUS
#
#       OrganizationID_DisplayEng OperatorTypeID_DisplayEng YearOfManuf  \
# 0              JAZZ AVIATION LP                COMMERCIAL        2005
# 1  AIR NORTH CHARTER & TRAINING                COMMERCIAL        1992
# 2  AIR NORTH CHARTER & TRAINING                COMMERCIAL        1992
# 3           VIH HELICOPTERS LTD                COMMERCIAL        1960
# 4               UNITED AIRLINES                COMMERCIAL        1993
#
#    NumberOfEngine OperationTypeID_DisplayEng   Latitude   Longitude  \
# 0             2.0              AIR TRANSPORT  56.550000  129.260000
# 1             2.0              AIR TRANSPORT  60.709444  135.067222
# 2             2.0              AIR TRANSPORT  60.709444  135.067222
# 3             2.0                HELILOGGING  52.185000  128.156667
# 4             2.0              AIR TRANSPORT  49.194722  123.183889
#
#                  OccDate   OccTime OccTypeID_DisplayEng  TotalFatalCount
# 0  6/11/2019 12:00:00 AM  13:35:00  INCIDENT REPORTABLE                0
# 1  6/12/2019 12:00:00 AM  22:33:00  INCIDENT REPORTABLE                0
# 2  6/12/2019 12:00:00 AM  22:33:00  INCIDENT REPORTABLE                0
# 3  5/24/2019 12:00:00 AM  12:00:00  INCIDENT REPORTABLE                0
# 4  6/12/2019 12:00:00 AM  14:40:00  INCIDENT REPORTABLE                0

# %%
df.shape
# Out:
# (68258, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68258 entries, 0 to 68257
# Data columns (total 17 columns):
# OccID                         68258 non-null int64
# OccNo                         68258 non-null object
# RegistrationNo                68257 non-null object
# AircraftTypeID_DisplayEng     68255 non-null object
# AircraftModelID_DisplayEng    67149 non-null object
# AircraftMakeID_DisplayEng     67203 non-null object
# OrganizationID_DisplayEng     53411 non-null object
# OperatorTypeID_DisplayEng     64618 non-null object
# YearOfManuf                   57940 non-null object
# NumberOfEngine                67826 non-null float64
# OperationTypeID_DisplayEng    64074 non-null object
# Latitude                      66695 non-null float64
# Longitude                     66699 non-null float64
# OccDate                       68258 non-null object
# OccTime                       67914 non-null object
# OccTypeID_DisplayEng          68258 non-null object
# TotalFatalCount               68258 non-null int64
# dtypes: float64(3), int64(2), object(12)
# memory usage: 9.4+ MB

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
msno.matrix(df)

# %%
#Total of missing values

df.isnull().sum().sum()
# Out:
# 39055

# %%
# fatal_col=[col for col in df.columns if 'Fatal' in col]
# #print (list(dfm.columns))
# print (fatal_col)

# %%
#Remove columns with >50% blank or null
#dfd = df.loc[:, df.isin([' ','NULL']).mean() <= .5]

# %%
#dfm = dfm.loc[:, dfm.eq("").mean().le(.5)]

# %%
dfd.shape #no columns dropped!
# Out:
# (68258, 17)

# %%
#Fill na values with mean
#dff = df.where(pd.notna(df), df.mean(), axis='columns')

# %%
#dff=dfm.apply(lambda x: x.fillna(x.mean()),axis=0)
#dff=dfm.fillna(0, inplace=True)

# %%
#dff.TotalFatalCount

# %%
#Remove columns with 0
#r_0 = dff.loc[:, (dff != 0).any(axis=0)]

# %%
#dff_ = dff.sort_values('OccID', ascending = False)

# %%
# dff.apply(pd.to_numeric, errors = 'ignore').info()

# %%
# dff = dff.drop_duplicates(subset = ['OccNo_x'])
#dff.dtypes

# %%
#Find columns with missing values
#null_columns=dfc_.columns[dfc_.isnull().any()]
#dfc_[null_columns].isnull().sum()

# %%
df.nunique()
# Out:
# OccID                         43855
# OccNo                         43855
# RegistrationNo                25241
# AircraftTypeID_DisplayEng        12
# AircraftModelID_DisplayEng     2269
# AircraftMakeID_DisplayEng       767
# OrganizationID_DisplayEng      3854
# OperatorTypeID_DisplayEng         8
# YearOfManuf                     167
# NumberOfEngine                    7
# OperationTypeID_DisplayEng       24
# Latitude                       3405
# Longitude                      5918
# OccDate                       14308
# OccTime                        1425
# OccTypeID_DisplayEng              2
# TotalFatalCount                  25
# dtype: int64

# %%
df.describe()
# Out:
#                OccID  NumberOfEngine      Latitude     Longitude  \
# count   68258.000000    67826.000000  66695.000000  66699.000000
# mean    96671.433239        1.803482     49.288104     91.630903
# std     33708.329076        0.782707      6.506231     23.748059
# min     45001.000000        0.000000      0.000000      0.000000
# 25%     66414.000000        1.000000     45.466667     74.566667
# 50%     91531.500000        2.000000     49.200000     84.516667
# 75%    128285.750000        2.000000     52.050000    114.016667
# max    152828.000000        8.000000     90.000000    180.000000
#
#        TotalFatalCount
# count     68258.000000
# mean          1.023147
# std          13.564872
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         261.000000

# %%
#Remove columns ending with Fre

# print (dff.columns[dff.columns.str.endswith('Fre')])

# dff_= dff.drop([col for col in dff.columns if 'Fre' in col], axis=1)
# dff.shape

#dff_ = dff.filter(regex=r'^((?!Fre).)*$')
# dfen = dff.loc[:, ~dff.columns.str.endswith('Fre')]#dff_ = dff.filter(regex=r'^((?!Fre).)*$')
# dfen = dff.loc[:, ~dff.columns.str.endswith('Fre')]

# %%
#dff_= dff.dropna(axis=1, thresh=int(0.5*len(dff)))

# %%
# dfen.apply(pd.to_numeric, errors = 'ignore').info()

# %%
#Finding data completeness
#msno.bar(dfen)

# %%
#pip install --upgrade setuptools

# %%
Long = df.Longitude * -1

# %%
sns.jointplot(x=Long.values, y=df.Latitude.values, ratio = 10)
plt.title('Lat and Longs')
# Out:
# Text(0.5,1,'Lat and Longs')

# %%
df.sample(5)
# Out:
#         OccID     OccNo  RegistrationNo AircraftTypeID_DisplayEng  \
# 42695   77361  A94W0005          C-GAIR                 AEROPLANE
# 18502  125423  A06P0064          C-FRRZ                HELICOPTER
# 2919   150257  A17A0052          C-FSRW                 AEROPLANE
# 7904   145281  A13W0166  REG-A13W0166-1                 AEROPLANE
# 42157   78001  A94W0026          C-FHAA                 AEROPLANE
#
#       AircraftModelID_DisplayEng AircraftMakeID_DisplayEng  \
# 42695                      421 A                    CESSNA
# 18502                        R44       ROBINSON HELICOPTER
# 2919                   DHC-8-400                BOMBARDIER
# 7904         CL-600-2D24 (RJ900)                  CANADAIR
# 42157                    DC-8-62                   DOUGLAS
#
#       OrganizationID_DisplayEng OperatorTypeID_DisplayEng YearOfManuf  \
# 42695    EXECUTIVE AIRLINES INC                COMMERCIAL        1969
# 18502               LAKELSE AIR                COMMERCIAL        1994
# 2919           JAZZ AVIATION LP                COMMERCIAL        2007
# 7904           JAZZ AVIATION LP                COMMERCIAL         NaN
# 42157      ADVANCE AIR CHARTERS                COMMERCIAL        1968
#
#        NumberOfEngine OperationTypeID_DisplayEng   Latitude   Longitude  \
# 42695             2.0              AIR TRANSPORT  56.800000  113.133333
# 18502             1.0              AIR TRANSPORT  54.466667  128.583333
# 2919              2.0              AIR TRANSPORT  46.161389   60.048056
# 7904              2.0              AIR TRANSPORT  51.116667  114.016667
# 42157             4.0              AIR TRANSPORT  51.100000  114.016667
#
#                      OccDate   OccTime OccTypeID_DisplayEng  TotalFatalCount
# 42695  1/12/1994 12:00:00 AM  10:30:00             ACCIDENT                0
# 18502  4/24/2006 12:00:00 AM  17:45:00             ACCIDENT                0
# 2919   7/19/2017 12:00:00 AM  12:15:00  INCIDENT REPORTABLE                0
# 7904   11/7/2013 12:00:00 AM  06:58:00  INCIDENT REPORTABLE                0
# 42157   3/8/1994 12:00:00 AM  06:38:00  INCIDENT REPORTABLE                0

# %%
df['OccDate'] = pd.to_datetime(df['OccDate'])
#df.OccDate

# %%
#df = pd.to_datetime(df['OccDate'], errors='coerce')

# %%
df.OccDate.dt.year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
# 5        2019
# 6        2019
# 7        2019
# 8        2019
# 9        2019
# 10       2019
# 11       2019
# 12       2019
# 13       2019
# 14       2019
# 15       2019
# 16       2019
# 17       2019
# 18       2019
# 19       2019
# 20       2019
# 21       2019
# 22       2019
# 23       2019
# 24       2019
# 25       2019
# 26       2019
# 27       2019
# 28       2019
# 29       2019
#          ...
# 68228    1976
# 68229    1976
# 68230    1976
# 68231    1976
# 68232    1976
# 68233    1976
# 68234    1976
# 68235    1976
# 68236    1976
# 68237    1976
# 68238    1976
# 68239    1976
# 68240    1976
# 68241    1976
# 68242    1976
# 68243    1976
# 68244    1976
# 68245    1976
# 68246    1976
# 68247    1976
# 68248    1976
# 68249    1976
# 68250    1976
# 68251    1976
# 68252    1976
# 68253    1976
# 68254    1976
# 68255    1976
# 68256    1976
# 68257    1976
# Name: OccDate, Length: 68258, dtype: int64

# %%
#importing plotly and cufflinks in offline mode
import plotly.plotly as py
import cufflinks as cf
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs
from plotly.offline import init_notebook_mode
from plotly.offline import plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Removed as there are few occurrences before 1976
#dfen.OccDate.dt.year.iplot(kind='histogram', bins=40, theme='white', title='Ocurrences per year')

# %%
#drop prior to 1976
old = df[(df.OccDate.dt.year < 1976)].index
df.drop(old, inplace=True)

# %%
df.OccDate.dt.year.iplot(kind='histogram', bins=50, theme='white', title='Ocurrences per year')
# Out:
# <div>
#
#
#             <div id="37646420-827f-4273-9e6f-ebb501889040" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("37646420-827f-4273-9e6f-ebb501889040")) {
#                     Plotly.newPlot(
#                         '37646420-827f-4273-9e6f-ebb501889040',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "OccDate", "nbinsx": 50, "opacity": 0.8, "orientation": "v", "type": "histogram", "uid": "9170e1a4-a16f-4c2c-8e13-e9e97760b486", "x": [2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2018, 2018, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2018, 2019, 2018, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2019, 2019, 2019, 2019,  ...

# %%
g = sns.FacetGrid(df,hue='AircraftMakeID_DisplayEng',palette='Set1',size=8,aspect=2)
g = g.map(plt.hist,'OrganizationID_DisplayEng',bins=20,alpha=0.5)
plt.legend()

# %%
px.scatter_matrix(df, dimensions=["OrganizationID_DisplayEng", "TotalFatalCount",
                               "OperatorTypeID_DisplayEng", "AircraftMakeID_DisplayEng"], color = 'OccDate')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-330-0db05bfeac10> in <module>
#       1 px.scatter_matrix(df, dimensions=["OrganizationID_DisplayEng", "TotalFatalCount",
# ----> 2                                "OperatorTypeID_DisplayEng", "AircraftMakeID_DisplayEng"], color = 'OccDate')
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\plotly_express\_chart_types.py in scatter_matrix(data_frame, dimensions, color, symbol, size, hover_name, hover_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, template, width, height)
#    1008     """
#    1009     return make_figure(
# -> 1010         args=locals(), constructor=go.Splom, layout_patch=dict(dragmode="select")
#    1011     )
#    1012
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\plotly_express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#     800     grouped = args["data_frame"].groupby(grouper, sort=False)
#     801
# --> 802     orders, sorted_group_names = get_orderings(args, grouper, grouped)
#     803
#     804     trace_names_by_frame = {}
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\plotly_express\_core.py in get_orderings(args, grouper, grouped)
#     779                 else:
#     780                     for val in uniques:
# --> 781                         if val not in orders[col]:
#     782                             orders[col].append(val)
#     783
#
# KeyboardInterrupt:

# %%
#dfen.TotalFatalCount

# %%
df.corr('pearson')
# Out:
#                     OccID  NumberOfEngine  Latitude  Longitude  \
# OccID            1.000000        0.132668 -0.054884  -0.003362
# NumberOfEngine   0.132668        1.000000 -0.061798  -0.174309
# Latitude        -0.054884       -0.061798  1.000000   0.395366
# Longitude       -0.003362       -0.174309  0.395366   1.000000
# TotalFatalCount -0.046402        0.139902 -0.199890  -0.110407
#
#                  TotalFatalCount
# OccID                  -0.046402
# NumberOfEngine          0.139902
# Latitude               -0.199890
# Longitude              -0.110407
# TotalFatalCount         1.000000

# %%
px.scatter(df, x="OrganizationID_DisplayEng", y="TotalFatalCount", size='pop', size_max=60)
