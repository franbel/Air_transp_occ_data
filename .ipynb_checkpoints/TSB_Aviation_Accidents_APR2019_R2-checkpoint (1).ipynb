# %% [markdown]
# ### Read and explore the datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quilt
import seaborn as sns
import missingno as msno
import plotly.offline
import plotly_express as px
import warnings
warnings.filterwarnings('ignore')


#init_notebook_mode

# pip install cufflinks
# pip install plotly_express
# cufflinks.__version__
# pip install cufflinks --upgrade
# pip install python-quilt
# pip install missingno

# %%
#Read datasets, no description available. ALl files available at 
# http://www.tsb.gc.ca/eng/stats/aviation/data-5.html. Adding conditions as warning
# received: Columns (+30 in total)have mixed types. Specify dtype option on 
# import or set low_memory=False.


df1 = pd.read_csv('ASISdb_MDOTW_VW_OCCURRENCE_PUBLIC.csv') 
#                   sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
df2 = pd.read_csv('ASISdb_MDOTW_VW_AIRCRAFT_PUBLIC.csv')
#                  sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
df3 = pd.read_csv('ASISdb_MDOTW_VW_EVENTS_AND_PHASES_PUBLIC.csv')
#df4 = pd.read_csv('ASISdb_MDOTW_VW_SURVIVABILITY_PUBLIC.csv')
dfo = pd.read_csv('23100018.csv')

# %% [markdown]
# ### Main Variables Definition
#
#  ASISdb_MDOTW_VW_OCCURRENCE_PUBLIC.csv : Indexed by 'OccID' & 'OccNo', includes also 'OccTypeID',                                                                        'OccTypeID_DisplayEng','Latitude', 'Longitude', 'OccDate', 'OccTypeID',

# %% [markdown]
# #### Full definition of contents  <http://www.tsb.gc.ca/eng/stats/aviation/2016/ssea-ssao-2016.html>
# <script src="http://www.tsb.gc.ca/includes/js/i18n/en.min.js"></script>

# %%
#Rename occid
df2 = df2.rename(index=str, columns={"occid": "OccID"})

# %%
df2.shape
# Out:
# (57227, 194)

# %%
df1.shape
# Out:
# (47226, 246)

# %%
df1.head()
# Out:
#     OccID     OccNo  AirportID AirportID_AirportName  AirportID_CountryID  \
# 0  152828  A19P0071     1984.0     Erik Nielsen Intl                  2.0
# 1  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 2  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 3  152826  A19P0070      109.0     (CAMPBELL ISLAND)                  2.0
# 4  152825  A19P0069     1912.0        Vancouver Intl                  2.0
#
#   AirportID_CountryID_DisplayEng AirportID_CountryID_DisplayFre  \
# 0                         CANADA                         CANADA
# 1                         CANADA                         CANADA
# 2                         CANADA                         CANADA
# 3                         CANADA                         CANADA
# 4                         CANADA                         CANADA
#
#    Airport_ProvinceID AirportID_ProvinceID_DisplayEng  \
# 0                24.0                           YUKON
# 1                24.0                           YUKON
# 2                24.0                           YUKON
# 3                12.0                BRITISH COLUMBIA
# 4                12.0                BRITISH COLUMBIA
#
#   AirportID_ProvinceID_DisplayFre                ...                 \
# 0                           YUKON                ...
# 1                           YUKON                ...
# 2                           YUKON                ...
# 3            COLOMBIE-BRITANNIQUE                ...
# 4            COLOMBIE-BRITANNIQUE                ...
#
#   InitialPositionEnum_DisplayFre  FinalPositionEnum  \
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
#
#    FinalPositionEnum_DisplayEng FinalPositionEnum_DisplayFre FullProcedureIND  \
# 0                           NaN                          NaN              NaN
# 1                           NaN                          NaN              NaN
# 2                           NaN                          NaN              NaN
# 3                           NaN                          NaN              NaN
# 4                           NaN                          NaN              NaN
#
#    FullProcedureIND_DisplayEng  FullProcedureIND_DisplayFre  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   SurfaceContaminationID SurfaceContaminationID_DisplayEng  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#   SurfaceContaminationID_DisplayFre
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 246 columns]

# %%
df3.shape
# Out:
# (105506, 14)

# %% [markdown]
# ### Finding unique values on datasets

# %%
df1u = df1.OccID.nunique()

# %%
df2u = df2.OccID.nunique()

# %%
df3u = df3.OccID.nunique()

# %%
unique_ = pd.DataFrame({'Dataset' :["AC","EVE", "PHA"],#"OCC","SUR"], 
                        "Unique":[df1u,df2u, df3u]})
unique_.sort_values(by="Unique", ascending=False)
# Out:
#   Dataset  Unique
# 0      AC   43855
# 1     EVE   43854
# 2     PHA   43814

# %% [markdown]
# ### Merging the three datasets with accidents information

# %%
# dfm = df1.merge(df2, how='left', left_on=('OccID'), right_on=('OccID'))
# .merge(df3, how='left', left_on=('OccID'), right_on=('OccID'))

# %%
from functools import reduce
dfs = [df1,df2,df3]
dfm = reduce(lambda left,right: pd.merge(left,right, on='OccID'), dfs)

# %%
dfm #dfm.TotalFatalCount
# Out:
#          OccID   OccNo_x  AirportID            AirportID_AirportName  \
# 0       152828  A19P0071     1984.0                Erik Nielsen Intl
# 1       152827  A19W0070     1984.0                Erik Nielsen Intl
# 2       152827  A19W0070     1984.0                Erik Nielsen Intl
# 3       152827  A19W0070     1984.0                Erik Nielsen Intl
# 4       152827  A19W0070     1984.0                Erik Nielsen Intl
# 5       152827  A19W0070     1984.0                Erik Nielsen Intl
# 6       152827  A19W0070     1984.0                Erik Nielsen Intl
# 7       152827  A19W0070     1984.0                Erik Nielsen Intl
# 8       152827  A19W0070     1984.0                Erik Nielsen Intl
# 9       152826  A19P0070      109.0                (CAMPBELL ISLAND)
# 10      152826  A19P0070      109.0                (CAMPBELL ISLAND)
# 11      152826  A19P0070      109.0                (CAMPBELL ISLAND)
# 12      152825  A19P0069     1912.0                   Vancouver Intl
# 13      152825  A19P0069     1912.0                   Vancouver Intl
# 14      152825  A19P0069     1912.0                   Vancouver Intl
# 15      152822  A19C0063     1366.0             POINTS NORTH LANDING
# 16      152820  A19C0062     2001.0  James Armstrong Richardson Intl
# 17      152818  A19Q0084     1448.0                 Jean Lesage Intl
# 18      152818  A19Q0084     1448.0                 Jean Lesage Intl
# 19      152814  A19F0155     4440.0        Ioannis Kapodistrias Intl
# 20      152813  A19A0040        NaN                              NaN
# 21      152813  A19A0040        NaN                              NaN
# 22      152813  A19A0040        NaN                              NaN
# 23      152812  A19Q0082      433.0      Pierre Elliott Trudeau Intl
# 24      152812  A19Q0082      433.0      Pierre Elliott Trudeau Intl
# 25      152812  A19Q0082      433.0      Pierre Elliott Trudeau Intl
# 26      152812  A19Q0082      433.0      Pierre Elliott Trudeau Intl
# 27      152812  A19Q0082      433.0      Pierre Elliott Trudeau Intl
# 28      152809  A19F0154        NaN                              NaN
# 29      152809  A19F0154        NaN                              NaN
# ...        ...       ...        ...                              ...
# 181434   45017  A76A0018        NaN                              NaN
# 181435   45016  A76A0017        NaN                              NaN
# 181436   45015  A76A0016        NaN                              NaN
# 181437   45015  A76A0016        NaN                              NaN
# 181438   45014  A76A0015        NaN                              NaN
# 181439   45014  A76A0015        NaN                              NaN
# 181440   45013  A76A0014        NaN                              NaN
# 181441   45012  A76A0013        NaN                              NaN
# 181442   45011  A76A0012        NaN                              NaN
# 181443   45010  A76A0011        NaN                              NaN
# 181444   45009  A76A0010        NaN                              NaN
# 181445   45009  A76A0010        NaN                              NaN
# 181446   45008  A76A0009        NaN                              NaN
# 181447   45008  A76A0009        NaN                              NaN
# 181448   45007  A76A0008        NaN                              NaN
# 181449   45006  A76A0007        NaN                              NaN
# 181450   45006  A76A0007        NaN                              NaN
# 181451   45005  A76A0006        NaN                              NaN
# 181452   45005  A76A0006        NaN                              NaN
# 181453   45005  A76A0006        NaN                              NaN
# 181454   45005  A76A0006        NaN                              NaN
# 181455   45004  A76A0005        NaN                              NaN
# 181456   45004  A76A0005        NaN                              NaN
# 181457   45004  A76A0005        NaN                              NaN
# 181458   45004  A76A0005        NaN                              NaN
# 181459   45003  A76A0004        NaN                              NaN
# 181460   45003  A76A0004        NaN                              NaN
# 181461   45002  A76A0003        NaN                              NaN
# 181462   45001  A76A0002        NaN                              NaN
# 181463   45001  A76A0002        NaN                              NaN
#
#         AirportID_CountryID AirportID_CountryID_DisplayEng  \
# 0                       2.0                         CANADA
# 1                       2.0                         CANADA
# 2                       2.0                         CANADA
# 3                       2.0                         CANADA
# 4                       2.0                         CANADA
# 5                       2.0                         CANADA
# 6                       2.0                         CANADA
# 7                       2.0                         CANADA
# 8                       2.0                         CANADA
# 9                       2.0                         CANADA
# 10                      2.0                         CANADA
# 11                      2.0                         CANADA
# 12                      2.0                         CANADA
# 13                      2.0                         CANADA
# 14                      2.0                         CANADA
# 15                      2.0                         CANADA
# 16                      2.0                         CANADA
# 17                      2.0                         CANADA
# 18                      2.0                         CANADA
# 19                    186.0                         GREECE
# 20                      NaN                            NaN
# 21                      NaN                            NaN
# 22                      NaN                            NaN
# 23                      2.0                         CANADA
# 24                      2.0                         CANADA
# 25                      2.0                         CANADA
# 26                      2.0                         CANADA
# 27                      2.0                         CANADA
# 28                      NaN                            NaN
# 29                      NaN                            NaN
# ...                     ...                            ...
# 181434                  NaN                            NaN
# 181435                  NaN                            NaN
# 181436                  NaN                            NaN
# 181437                  NaN                            NaN
# 181438                  NaN                            NaN
# 181439                  NaN                            NaN
# 181440                  NaN                            NaN
# 181441                  NaN                            NaN
# 181442                  NaN                            NaN
# 181443                  NaN                            NaN
# 181444                  NaN                            NaN
# 181445                  NaN                            NaN
# 181446                  NaN                            NaN
# 181447                  NaN                            NaN
# 181448                  NaN                            NaN
# 181449                  NaN                            NaN
# 181450                  NaN                            NaN
# 181451                  NaN                            NaN
# 181452                  NaN                            NaN
# 181453                  NaN                            NaN
# 181454                  NaN                            NaN
# 181455                  NaN                            NaN
# 181456                  NaN                            NaN
# 181457                  NaN                            NaN
# 181458                  NaN                            NaN
# 181459                  NaN                            NaN
# 181460                  NaN                            NaN
# 181461                  NaN                            NaN
# 181462                  NaN                            NaN
# 181463                  NaN                            NaN
#
#        AirportID_CountryID_DisplayFre  Airport_ProvinceID  \
# 0                              CANADA                24.0
# 1                              CANADA                24.0
# 2                              CANADA                24.0
# 3                              CANADA                24.0
# 4                              CANADA                24.0
# 5                              CANADA                24.0
# 6                              CANADA                24.0
# 7                              CANADA                24.0
# 8                              CANADA                24.0
# 9                              CANADA                12.0
# 10                             CANADA                12.0
# 11                             CANADA                12.0
# 12                             CANADA                12.0
# 13                             CANADA                12.0
# 14                             CANADA                12.0
# 15                             CANADA                10.0
# 16                             CANADA                 9.0
# 17                             CANADA                 4.0
# 18                             CANADA                 4.0
# 19                              GRECE                 NaN
# 20                                NaN                 NaN
# 21                                NaN                 NaN
# 22                                NaN                 NaN
# 23                             CANADA                 4.0
# 24                             CANADA                 4.0
# 25                             CANADA                 4.0
# 26                             CANADA                 4.0
# 27                             CANADA                 4.0
# 28                                NaN                 NaN
# 29                                NaN                 NaN
# ...                               ...                 ...
# 181434                            NaN                 NaN
# 181435                            NaN                 NaN
# 181436                            NaN                 NaN
# 181437                            NaN                 NaN
# 181438                            NaN                 NaN
# 181439                            NaN                 NaN
# 181440                            NaN                 NaN
# 181441                            NaN                 NaN
# 181442                            NaN                 NaN
# 181443                            NaN                 NaN
# 181444                            NaN                 NaN
# 181445                            NaN                 NaN
# 181446                            NaN                 NaN
# 181447                            NaN                 NaN
# 181448                            NaN                 NaN
# 181449                            NaN                 NaN
# 181450                            NaN                 NaN
# 181451                            NaN                 NaN
# 181452                            NaN                 NaN
# 181453                            NaN                 NaN
# 181454                            NaN                 NaN
# 181455                            NaN                 NaN
# 181456                            NaN                 NaN
# 181457                            NaN                 NaN
# 181458                            NaN                 NaN
# 181459                            NaN                 NaN
# 181460                            NaN                 NaN
# 181461                            NaN                 NaN
# 181462                            NaN                 NaN
# 181463                            NaN                 NaN
#
#        AirportID_ProvinceID_DisplayEng AirportID_ProvinceID_DisplayFre  \
# 0                                YUKON                           YUKON
# 1                                YUKON                           YUKON
# 2                                YUKON                           YUKON
# 3                                YUKON                           YUKON
# 4                                YUKON                           YUKON
# 5                                YUKON                           YUKON
# 6                                YUKON                           YUKON
# 7                                YUKON                           YUKON
# 8                                YUKON                           YUKON
# 9                     BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 10                    BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 11                    BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 12                    BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 13                    BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 14                    BRITISH COLUMBIA            COLOMBIE-BRITANNIQUE
# 15                        SASKATCHEWAN                    SASKATCHEWAN
# 16                            MANITOBA                        MANITOBA
# 17                              QUEBEC                          QUEBEC
# 18                              QUEBEC                          QUEBEC
# 19                                 NaN                             NaN
# 20                                 NaN                             NaN
# 21                                 NaN                             NaN
# 22                                 NaN                             NaN
# 23                              QUEBEC                          QUEBEC
# 24                              QUEBEC                          QUEBEC
# 25                              QUEBEC                          QUEBEC
# 26                              QUEBEC                          QUEBEC
# 27                              QUEBEC                          QUEBEC
# 28                                 NaN                             NaN
# 29                                 NaN                             NaN
# ...                                ...                             ...
# 181434                             NaN                             NaN
# 181435                             NaN                             NaN
# 181436                             NaN                             NaN
# 181437                             NaN                             NaN
# 181438                             NaN                             NaN
# 181439                             NaN                             NaN
# 181440                             NaN                             NaN
# 181441                             NaN                             NaN
# 181442                             NaN                             NaN
# 181443                             NaN                             NaN
# 181444                             NaN                             NaN
# 181445                             NaN                             NaN
# 181446                             NaN                             NaN
# 181447                             NaN                             NaN
# 181448                             NaN                             NaN
# 181449                             NaN                             NaN
# 181450                             NaN                             NaN
# 181451                             NaN                             NaN
# 181452                             NaN                             NaN
# 181453                             NaN                             NaN
# 181454                             NaN                             NaN
# 181455                             NaN                             NaN
# 181456                             NaN                             NaN
# 181457                             NaN                             NaN
# 181458                             NaN                             NaN
# 181459                             NaN                             NaN
# 181460                             NaN                             NaN
# 181461                             NaN                             NaN
# 181462                             NaN                             NaN
# 181463                             NaN                             NaN
#
#                               ...                         EventPhaseSequence  \
# 0                             ...                                          1
# 1                             ...                                          1
# 2                             ...                                          2
# 3                             ...                                          3
# 4                             ...                                          4
# 5                             ...                                          1
# 6                             ...                                          2
# 7                             ...                                          3
# 8                             ...                                          4
# 9                             ...                                          1
# 10                            ...                                          2
# 11                            ...                                          3
# 12                            ...                                          1
# 13                            ...                                          2
# 14                            ...                                          3
# 15                            ...                                          1
# 16                            ...                                          1
# 17                            ...                                          1
# 18                            ...                                          2
# 19                            ...                                          1
# 20                            ...                                          1
# 21                            ...                                          2
# 22                            ...                                          3
# 23                            ...                                          2
# 24                            ...                                          5
# 25                            ...                                          4
# 26                            ...                                          3
# 27                            ...                                          1
# 28                            ...                                          1
# 29                            ...                                          3
# ...                           ...                                        ...
# 181434                        ...                                          2
# 181435                        ...                                          1
# 181436                        ...                                          1
# 181437                        ...                                          2
# 181438                        ...                                          1
# 181439                        ...                                          2
# 181440                        ...                                          1
# 181441                        ...                                          1
# 181442                        ...                                          1
# 181443                        ...                                          1
# 181444                        ...                                          1
# 181445                        ...                                          2
# 181446                        ...                                          1
# 181447                        ...                                          2
# 181448                        ...                                          1
# 181449                        ...                                          1
# 181450                        ...                                          2
# 181451                        ...                                          1
# 181452                        ...                                          2
# 181453                        ...                                          1
# 181454                        ...                                          2
# 181455                        ...                                          1
# 181456                        ...                                          2
# 181457                        ...                                          1
# 181458                        ...                                          2
# 181459                        ...                                          1
# 181460                        ...                                          2
# 181461                        ...                                          1
# 181462                        ...                                          1
# 181463                        ...                                          2
#
#                                       EventID_DisplayEng  \
# 0       Flight crew incapacitation/illness/medical issue
# 1                                Smoke - Passenger cabin
# 2                                        Smoke - Cockpit
# 3                                            Smoke - APU
# 4               Declared Emergency/Priority/ARFF Standby
# 5                                Smoke - Passenger cabin
# 6                                        Smoke - Cockpit
# 7                                            Smoke - APU
# 8               Declared Emergency/Priority/ARFF Standby
# 9                             Smoke or fumes in aircraft
# 10                               Electrical power system
# 11                                       Smoke - Cockpit
# 12                                     Technical reasons
# 13                               Electrical power system
# 14              Declared Emergency/Priority/ARFF Standby
# 15                   Unintentional drop of external load
# 16                         Cabin crew - injury sustained
# 17                             Flight compartment window
# 18               Declared emergency - Urgency (PAN call)
# 19                                  Cabin crew - medical
# 20                                Dragged wing/pod/float
# 21                                 Nosed down/overturned
# 22                                         Aircraft sank
# 23                                     Engine oil system
# 24                         Diversion - technical reasons
# 25               Declared emergency - Urgency (PAN call)
# 26                                  INTENTIONAL SHUTDOWN
# 27                              Engine indicating system
# 28                                        Noise / rattle
# 29                                 Precautionary descent
# ...                                                  ...
# 181434                      Wheels down landing on water
# 181435                   Aeroplane flight path deviation
# 181436                Aircraft collision - level terrain
# 181437         Collision aircraft - cable/wire/powerline
# 181438                         POWER LOSS - FIRST ENGINE
# 181439                Aircraft collision - level terrain
# 181440         Collision aircraft-tree / tall vegetation
# 181441                   Aeroplane flight path deviation
# 181442                            Aeroplane - mush/stall
# 181443                            Aeroplane - mush/stall
# 181444                                        Undershoot
# 181445                                 Aircraft handling
# 181446                         POWER LOSS - FIRST ENGINE
# 181447         Collision aircraft - cable/wire/powerline
# 181448                                      Landing gear
# 181449                      Collision aircraft-snow bank
# 181450                                 Main landing gear
# 181451                   Aeroplane flight path deviation
# 181452                      Collision aircraft-snow bank
# 181453                   Aeroplane flight path deviation
# 181454                      Collision aircraft-snow bank
# 181455                        Collision aircraft-vehicle
# 181456                      Injuries-propeller/jet blast
# 181457                        Collision aircraft-vehicle
# 181458                      Injuries-propeller/jet blast
# 181459                Aircraft collision - level terrain
# 181460                      Collision aircraft-snow bank
# 181461                   Aeroplane flight path deviation
# 181462                         POWER LOSS - FIRST ENGINE
# 181463                                      Hard landing
#
#                                        EventID_DisplayFre  \
# 0            Maladie/Incapacité de l'équipage de conduite
# 1                                Fumée - Cabine passagers
# 2                               Fumée - Poste de pilotage
# 3                                             Fumée - APU
# 4                               Déclaration d'une urgence
# 5                                Fumée - Cabine passagers
# 6                               Fumée - Poste de pilotage
# 7                                             Fumée - APU
# 8                               Déclaration d'une urgence
# 9               La fumée ou des émanations dans l'aéronef
# 10                        Circuit alimentation électrique
# 11                              Fumée - Poste de pilotage
# 12                    Déroutement pour raisons techniques
# 13                        Circuit alimentation électrique
# 14                              Déclaration d'une urgence
# 15      Abandon ou largage non intentionnel de la char...
# 16         Personnel navigant commercial (PNC) - blessure
# 17                      5610 Pare-brise poste de pilotage
# 18                             Urgence déclarée - PAN PAN
# 19      Personnel navigant commercial (PNC) incapable ...
# 20      Heurt, traînée ou éraflement voilure/rotor/nac...
# 21                                         Piqué/Capotage
# 22              Dégâts résultant d'un aéronef qui a coulé
# 23                                   Circuit huile moteur
# 24                    Déroutement pour raisons techniques
# 25                             Urgence déclarée - PAN PAN
# 26                                     ARRÊT INTENTIONNEL
# 27                              Système indicateur moteur
# 28                                     Bruits / cliquetis
# 29                                 Descente de précaution
# ...                                                   ...
# 181434                            Amerrissage train sorti
# 181435  Perte de contrôle ou écart par rapport à la tr...
# 181436  Collision d'un aéronef avec terrain plat/plan ...
# 181437  Collision d'aéronef avec ligne transmission, c...
# 181438                PERTE DE PUISSANCE - PREMIER MOTEUR
# 181439  Collision d'un aéronef avec terrain plat/plan ...
# 181440    Collision d'aéronef avec arbre/végétation haute
# 181441  Perte de contrôle ou écart par rapport à la tr...
# 181442  Vol au second régime/décrochage (aéronef à voi...
# 181443  Vol au second régime/décrochage (aéronef à voi...
# 181444                            Atterrissage trop court
# 181445                              Conduite de l'aéronef
# 181446                PERTE DE PUISSANCE - PREMIER MOTEUR
# 181447  Collision d'aéronef avec ligne transmission, c...
# 181448                               Train d’atterrissage
# 181449                   Collision d'aéronef avec congère
# 181450     Train d'atterrissage principal (ATA Code:3210)
# 181451  Perte de contrôle ou écart par rapport à la tr...
# 181452                   Collision d'aéronef avec congère
# 181453  Perte de contrôle ou écart par rapport à la tr...
# 181454                   Collision d'aéronef avec congère
# 181455                  Collision d'aéronef avec véhicule
# 181456  Blessures causées par le contact avec un souff...
# 181457                  Collision d'aéronef avec véhicule
# 181458  Blessures causées par le contact avec un souff...
# 181459  Collision d'un aéronef avec terrain plat/plan ...
# 181460                   Collision d'aéronef avec congère
# 181461  Perte de contrôle ou écart par rapport à la tr...
# 181462                PERTE DE PUISSANCE - PREMIER MOTEUR
# 181463                                   Atterrissage dur
#
#                                          FullEventDescEng  \
# 0       [Aircraft operation general].[Flight crew].[Fl...
# 1       [Aircraft/system/component related event (Airc...
# 2       [Aircraft/system/component related event (Airc...
# 3       [Aircraft/system/component related event (Airc...
# 4       [Consequential events].[Declared Emergency/Pri...
# 5       [Aircraft/system/component related event (Airc...
# 6       [Aircraft/system/component related event (Airc...
# 7       [Aircraft/system/component related event (Airc...
# 8       [Consequential events].[Declared Emergency/Pri...
# 9       [Aircraft operation general].[Aircraft fire/ex...
# 10      [Aircraft/system/component related event (Airc...
# 11      [Aircraft/system/component related event (Airc...
# 12      [Aircraft operation general].[Aircraft diversi...
# 13      [Aircraft/system/component related event (Airc...
# 14      [Consequential events].[Declared Emergency/Pri...
# 15      [Aircraft operation general].[Helicopter exter...
# 16      [Aircraft operation general].[Cabin safety].[C...
# 17      [Aircraft/system/component related event (Airc...
# 18      [Consequential events].[Declared Emergency/Pri...
# 19      [Aircraft operation general].[Cabin safety].[C...
# 20      [Aircraft operation general].[Aircraft handlin...
# 21         [Consequential events].[Nosed down/overturned]
# 22      [Aircraft operation general].[Damage to aircra...
# 23      [Aircraft/system/component related event (Airc...
# 24      [Consequential events].[Diversion].[Diversion ...
# 25      [Consequential events].[Declared Emergency/Pri...
# 26      [Aircraft/system/component related event (Airc...
# 27      [Aircraft/system/component related event (Airc...
# 28      [Aircraft/system/component related event (Airc...
# 29         [Consequential events].[Precautionary descent]
# ...                                                   ...
# 181434  [Aircraft operation general].[Aircraft handlin...
# 181435  [Aircraft operation general].[Aeroplane flight...
# 181436  [Aircraft operation general].[Aircraft - colli...
# 181437  [Aircraft operation general].[Aircraft - colli...
# 181438  [Aircraft/system/component related event (Airc...
# 181439  [Aircraft operation general].[Aircraft - colli...
# 181440  [Aircraft operation general].[Aircraft - colli...
# 181441  [Aircraft operation general].[Aeroplane flight...
# 181442  [Aircraft operation general].[Aeroplane flight...
# 181443  [Aircraft operation general].[Aeroplane flight...
# 181444  [Aircraft operation general].[Aircraft handlin...
# 181445   [Aircraft operation general].[Aircraft handling]
# 181446  [Aircraft/system/component related event (Airc...
# 181447  [Aircraft operation general].[Aircraft - colli...
# 181448  [Aircraft/system/component related event (Airc...
# 181449  [Aircraft operation general].[Aircraft - colli...
# 181450  [Aircraft/system/component related event (Airc...
# 181451  [Aircraft operation general].[Aeroplane flight...
# 181452  [Aircraft operation general].[Aircraft - colli...
# 181453  [Aircraft operation general].[Aeroplane flight...
# 181454  [Aircraft operation general].[Aircraft - colli...
# 181455  [Aircraft operation general].[Aircraft - colli...
# 181456  [Aircraft operation general].[Injuries to pers...
# 181457  [Aircraft operation general].[Aircraft - colli...
# 181458  [Aircraft operation general].[Injuries to pers...
# 181459  [Aircraft operation general].[Aircraft - colli...
# 181460  [Aircraft operation general].[Aircraft - colli...
# 181461  [Aircraft operation general].[Aeroplane flight...
# 181462  [Aircraft/system/component related event (Airc...
# 181463  [Aircraft operation general].[Aircraft handlin...
#
#                                          FullEventDescFre  PhaseID  \
# 0       [Exploitation de l'aéronef - général].[Équipag...    184.0
# 1       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 2       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 3       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 4       [Evénements résultants, conséquences].[Déclara...    211.0
# 5       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 6       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 7       [Evénement aéronef/système/composant (Aéronef/...    211.0
# 8       [Evénements résultants, conséquences].[Déclara...    211.0
# 9       [Exploitation de l'aéronef - général].[Aéronef...     92.0
# 10      [Evénement aéronef/système/composant (Aéronef/...     92.0
# 11      [Evénement aéronef/système/composant (Aéronef/...     92.0
# 12      [Exploitation de l'aéronef - général].[Déroute...    213.0
# 13      [Evénement aéronef/système/composant (Aéronef/...    213.0
# 14      [Evénements résultants, conséquences].[Déclara...    213.0
# 15      [Exploitation de l'aéronef - général].[Hélicop...    135.0
# 16      [Exploitation de l'aéronef - général].[Sécurit...    184.0
# 17      [Evénement aéronef/système/composant (Aéronef/...    178.0
# 18      [Evénements résultants, conséquences].[Déclara...    178.0
# 19      [Exploitation de l'aéronef - général].[Sécurit...    183.0
# 20      [Exploitation de l'aéronef - général].[Conduit...    219.0
# 21      [Evénements résultants, conséquences].[Piqué/C...    219.0
# 22      [Exploitation de l'aéronef - général].[Dégâts ...    219.0
# 23      [Evénement aéronef/système/composant (Aéronef/...    216.0
# 24      [Evénements résultants, conséquences].[Déroute...    216.0
# 25      [Evénements résultants, conséquences].[Déclara...    216.0
# 26      [Evénement aéronef/système/composant (Aéronef/...    216.0
# 27      [Evénement aéronef/système/composant (Aéronef/...    216.0
# 28      [Evénement aéronef/système/composant (Aéronef/...    184.0
# 29      [Evénements résultants, conséquences].[Descent...    184.0
# ...                                                   ...      ...
# 181434  [Exploitation de l'aéronef - général].[Conduit...    198.0
# 181435  [Exploitation de l'aéronef - général].[Perte d...    218.0
# 181436  [Exploitation de l'aéronef - général].[Collisi...    184.0
# 181437  [Exploitation de l'aéronef - général].[Collisi...    176.0
# 181438  [Evénement aéronef/système/composant (Aéronef/...    184.0
# 181439  [Exploitation de l'aéronef - général].[Collisi...    184.0
# 181440  [Exploitation de l'aéronef - général].[Collisi...    216.0
# 181441  [Exploitation de l'aéronef - général].[Perte d...    194.0
# 181442  [Exploitation de l'aéronef - général].[Perte d...    187.0
# 181443  [Exploitation de l'aéronef - général].[Perte d...    216.0
# 181444  [Exploitation de l'aéronef - général].[Conduit...    198.0
# 181445  [Exploitation de l'aéronef - général].[Conduit...    198.0
# 181446  [Evénement aéronef/système/composant (Aéronef/...    184.0
# 181447  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181448  [Evénement aéronef/système/composant (Aéronef/...    234.0
# 181449  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181450  [Evénement aéronef/système/composant (Aéronef/...    194.0
# 181451  [Exploitation de l'aéronef - général].[Perte d...    194.0
# 181452  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181453  [Exploitation de l'aéronef - général].[Perte d...    194.0
# 181454  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181455  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181456  [Exploitation de l'aéronef - général].[Blessur...    194.0
# 181457  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181458  [Exploitation de l'aéronef - général].[Blessur...    194.0
# 181459  [Exploitation de l'aéronef - général].[Collisi...    184.0
# 181460  [Exploitation de l'aéronef - général].[Collisi...    194.0
# 181461  [Exploitation de l'aéronef - général].[Perte d...    218.0
# 181462  [Evénement aéronef/système/composant (Aéronef/...    108.0
# 181463  [Exploitation de l'aéronef - général].[Conduit...    108.0
#
#                          PhaseID_DisplayEng  \
# 0                                    Cruise
# 1            Standing : Engine(s) Shut Down
# 2            Standing : Engine(s) Shut Down
# 3            Standing : Engine(s) Shut Down
# 4            Standing : Engine(s) Shut Down
# 5            Standing : Engine(s) Shut Down
# 6            Standing : Engine(s) Shut Down
# 7            Standing : Engine(s) Shut Down
# 8            Standing : Engine(s) Shut Down
# 9                                  En-route
# 10                                 En-route
# 11                                 En-route
# 12                                 Take-off
# 13                                 Take-off
# 14                                 Take-off
# 15                            Initial climb
# 16                                   Cruise
# 17                    Intermediate approach
# 18                    Intermediate approach
# 19      Climb to cruising level or altitude
# 20                          Take-off: Other
# 21                          Take-off: Other
# 22                          Take-off: Other
# 23                            Initial climb
# 24                            Initial climb
# 25                            Initial climb
# 26                            Initial climb
# 27                            Initial climb
# 28                                   Cruise
# 29                                   Cruise
# ...                                     ...
# 181434                  Level off-touchdown
# 181435                         Take-off run
# 181436                               Cruise
# 181437                       Final approach
# 181438                               Cruise
# 181439                               Cruise
# 181440                        Initial climb
# 181441                         Landing roll
# 181442                      En-route: Other
# 181443                        Initial climb
# 181444                  Level off-touchdown
# 181445                  Level off-touchdown
# 181446                               Cruise
# 181447                         Landing roll
# 181448                       Taxiing: Other
# 181449                         Landing roll
# 181450                         Landing roll
# 181451                         Landing roll
# 181452                         Landing roll
# 181453                         Landing roll
# 181454                         Landing roll
# 181455                         Landing roll
# 181456                         Landing roll
# 181457                         Landing roll
# 181458                         Landing roll
# 181459                               Cruise
# 181460                         Landing roll
# 181461                         Take-off run
# 181462                       Run-on landing
# 181463                       Run-on landing
#
#                                  PhaseID_DisplayFre  \
# 0                                         Croisière
# 1                       Stationné - arrêt du moteur
# 2                       Stationné - arrêt du moteur
# 3                       Stationné - arrêt du moteur
# 4                       Stationné - arrêt du moteur
# 5                       Stationné - arrêt du moteur
# 6                       Stationné - arrêt du moteur
# 7                       Stationné - arrêt du moteur
# 8                       Stationné - arrêt du moteur
# 9                                          En route
# 10                                         En route
# 11                                         En route
# 12                                        Décollage
# 13                                        Décollage
# 14                                        Décollage
# 15                                  Montée initiale
# 16                                        Croisière
# 17                           Approche intermédiaire
# 18                           Approche intermédiaire
# 19      Montée au niveau ou l'altitude de croisière
# 20                                Décollage - autre
# 21                                Décollage - autre
# 22                                Décollage - autre
# 23                                  Montée initiale
# 24                                  Montée initiale
# 25                                  Montée initiale
# 26                                  Montée initiale
# 27                                  Montée initiale
# 28                                        Croisière
# 29                                        Croisière
# ...                                             ...
# 181434                    Arrondi/toucher des roues
# 181435                       Roulement au décollage
# 181436                                    Croisière
# 181437                              Approche finale
# 181438                                    Croisière
# 181439                                    Croisière
# 181440                              Montée initiale
# 181441                   Roulement à l'atterrissage
# 181442                             En route - autre
# 181443                              Montée initiale
# 181444                    Arrondi/toucher des roues
# 181445                    Arrondi/toucher des roues
# 181446                                    Croisière
# 181447                   Roulement à l'atterrissage
# 181448                              Roulage - autre
# 181449                   Roulement à l'atterrissage
# 181450                   Roulement à l'atterrissage
# 181451                   Roulement à l'atterrissage
# 181452                   Roulement à l'atterrissage
# 181453                   Roulement à l'atterrissage
# 181454                   Roulement à l'atterrissage
# 181455                   Roulement à l'atterrissage
# 181456                   Roulement à l'atterrissage
# 181457                   Roulement à l'atterrissage
# 181458                   Roulement à l'atterrissage
# 181459                                    Croisière
# 181460                   Roulement à l'atterrissage
# 181461                       Roulement au décollage
# 181462                         Atterrissage glissé
# 181463                         Atterrissage glissé
#
#                                          FullPhaseDescEng  \
# 0       [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 1       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 2       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 3       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 4       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 5       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 6       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 7       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 8       [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 9                                 [HELICOPTER].[En-route]
# 10                                [HELICOPTER].[En-route]
# 11                                [HELICOPTER].[En-route]
# 12               [POWERED FIXED-WING AIRCRAFT].[Take-off]
# 13               [POWERED FIXED-WING AIRCRAFT].[Take-off]
# 14               [POWERED FIXED-WING AIRCRAFT].[Take-off]
# 15                [HELICOPTER].[Take-off].[Initial climb]
# 16      [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 17      [POWERED FIXED-WING AIRCRAFT].[Approach].[Inte...
# 18      [POWERED FIXED-WING AIRCRAFT].[Approach].[Inte...
# 19      [POWERED FIXED-WING AIRCRAFT].[En-route].[Clim...
# 20      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Take...
# 21      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Take...
# 22      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Take...
# 23      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 24      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 25      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 26      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 27      [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 28      [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 29      [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# ...                                                   ...
# 181434  [POWERED FIXED-WING AIRCRAFT].[Landing].[Level...
# 181435  [POWERED FIXED-WING AIRCRAFT].[Take-off].[Take...
# 181436  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 181437  [POWERED FIXED-WING AIRCRAFT].[Approach].[Fina...
# 181438  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 181439  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 181440  [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 181441  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181442  [POWERED FIXED-WING AIRCRAFT].[En-route].[En-r...
# 181443  [POWERED FIXED-WING AIRCRAFT].[Take-off].[Init...
# 181444  [POWERED FIXED-WING AIRCRAFT].[Landing].[Level...
# 181445  [POWERED FIXED-WING AIRCRAFT].[Landing].[Level...
# 181446  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 181447  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181448  [POWERED FIXED-WING AIRCRAFT].[Taxi].[Taxiing:...
# 181449  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181450  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181451  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181452  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181453  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181454  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181455  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181456  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181457  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181458  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181459  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 181460  [POWERED FIXED-WING AIRCRAFT].[Landing].[Landi...
# 181461  [POWERED FIXED-WING AIRCRAFT].[Take-off].[Take...
# 181462            [HELICOPTER].[Landing].[Run-on landing]
# 181463            [HELICOPTER].[Landing].[Run-on landing]
#
#                                          FullPhaseDescFre
# 0       [Aéronef à voilure fixe - motorisé].[En route]...
# 1       [Aéronef à voilure fixe - motorisé].[Stationne...
# 2       [Aéronef à voilure fixe - motorisé].[Stationne...
# 3       [Aéronef à voilure fixe - motorisé].[Stationne...
# 4       [Aéronef à voilure fixe - motorisé].[Stationne...
# 5       [Aéronef à voilure fixe - motorisé].[Stationne...
# 6       [Aéronef à voilure fixe - motorisé].[Stationne...
# 7       [Aéronef à voilure fixe - motorisé].[Stationne...
# 8       [Aéronef à voilure fixe - motorisé].[Stationne...
# 9                                [Hélicoptère].[En route]
# 10                               [Hélicoptère].[En route]
# 11                               [Hélicoptère].[En route]
# 12        [Aéronef à voilure fixe - motorisé].[Décollage]
# 13        [Aéronef à voilure fixe - motorisé].[Décollage]
# 14        [Aéronef à voilure fixe - motorisé].[Décollage]
# 15            [Hélicoptère].[Décollage].[Montée initiale]
# 16      [Aéronef à voilure fixe - motorisé].[En route]...
# 17      [Aéronef à voilure fixe - motorisé].[Approche]...
# 18      [Aéronef à voilure fixe - motorisé].[Approche]...
# 19      [Aéronef à voilure fixe - motorisé].[En route]...
# 20      [Aéronef à voilure fixe - motorisé].[Décollage...
# 21      [Aéronef à voilure fixe - motorisé].[Décollage...
# 22      [Aéronef à voilure fixe - motorisé].[Décollage...
# 23      [Aéronef à voilure fixe - motorisé].[Décollage...
# 24      [Aéronef à voilure fixe - motorisé].[Décollage...
# 25      [Aéronef à voilure fixe - motorisé].[Décollage...
# 26      [Aéronef à voilure fixe - motorisé].[Décollage...
# 27      [Aéronef à voilure fixe - motorisé].[Décollage...
# 28      [Aéronef à voilure fixe - motorisé].[En route]...
# 29      [Aéronef à voilure fixe - motorisé].[En route]...
# ...                                                   ...
# 181434  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181435  [Aéronef à voilure fixe - motorisé].[Décollage...
# 181436  [Aéronef à voilure fixe - motorisé].[En route]...
# 181437  [Aéronef à voilure fixe - motorisé].[Approche]...
# 181438  [Aéronef à voilure fixe - motorisé].[En route]...
# 181439  [Aéronef à voilure fixe - motorisé].[En route]...
# 181440  [Aéronef à voilure fixe - motorisé].[Décollage...
# 181441  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181442  [Aéronef à voilure fixe - motorisé].[En route]...
# 181443  [Aéronef à voilure fixe - motorisé].[Décollage...
# 181444  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181445  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181446  [Aéronef à voilure fixe - motorisé].[En route]...
# 181447  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181448  [Aéronef à voilure fixe - motorisé].[Circulati...
# 181449  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181450  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181451  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181452  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181453  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181454  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181455  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181456  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181457  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181458  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181459  [Aéronef à voilure fixe - motorisé].[En route]...
# 181460  [Aéronef à voilure fixe - motorisé].[Atterriss...
# 181461  [Aéronef à voilure fixe - motorisé].[Décollage...
# 181462  [Hélicoptère].[Atterrissage].[Atterrissage gli...
# 181463  [Hélicoptère].[Atterrissage].[Atterrissage gli...
#
# [181464 rows x 452 columns]

# %% [markdown]
# ### Preprocessing dataset with information about movements

# %%
dfo.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Class of operation',
#        'Rank and number of movements', 'UOM', 'UOM_ID', 'SCALAR_FACTOR',
#        'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL',
#        'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
mov = dfo.groupby(['REF_DATE','GEO', 'Class of operation', 'VALUE'])

# %%
mov.first()
# Out:
#                                                                                                                 DGUID  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18               NaN
#                                                                                                  56769            NaN
#                                                             Local movements                      5                NaN
#                                                                                                  79369            NaN
#                                                             Total, itinerant and local movements 12               NaN
#                                                                                                  136138           NaN
#          Alberta                                            Itinerant movements                  452402   2016A000248
#                                                             Local movements                      175239   2016A000248
#                                                             Total, itinerant and local movements 627641   2016A000248
#          Boundary Bay, British Columbia                     Itinerant movements                  14               NaN
#                                                                                                  68630            NaN
#                                                             Local movements                      1                NaN
#                                                                                                  139509           NaN
#                                                             Total, itinerant and local movements 4                NaN
#                                                                                                  208139           NaN
#          British Columbia                                   Itinerant movements                  784723   2016A000259
#                                                             Local movements                      443831   2016A000259
#                                                             Total, itinerant and local movements 1228554  2016A000259
#          Calgary International, Alberta                     Itinerant movements                  3                NaN
#                                                                                                  224561           NaN
#                                                             Local movements                      37               NaN
#                                                                                                  14397            NaN
#                                                             Total, itinerant and local movements 3                NaN
#                                                                                                  238958           NaN
#          Calgary/Springbank, Alberta                        Itinerant movements                  27               NaN
#                                                                                                  41491            NaN
#                                                             Local movements                      3                NaN
#                                                                                                  87107            NaN
#                                                             Total, itinerant and local movements 13               NaN
#                                                                                                  128598           NaN
# ...                                                                                                               ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170            NaN
#                                                             Total, itinerant and local movements 40               NaN
#                                                                                                  38470            NaN
#          Windsor, Ontario                                   Itinerant movements                  40               NaN
#                                                                                                  23003            NaN
#                                                             Local movements                      24               NaN
#                                                                                                  19697            NaN
#                                                             Total, itinerant and local movements 36               NaN
#                                                                                                  42700            NaN
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7                NaN
#                                                                                                  109314           NaN
#                                                             Local movements                      30               NaN
#                                                                                                  9038             NaN
#                                                             Total, itinerant and local movements 15               NaN
#                                                                                                  118352           NaN
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26               NaN
#                                                                                                  42769            NaN
#                                                             Local movements                      5                NaN
#                                                                                                  75236            NaN
#                                                             Total, itinerant and local movements 16               NaN
#                                                                                                  118005           NaN
#          Yellowknife, Northwest Territories                 Itinerant movements                  25               NaN
#                                                                                                  44410            NaN
#                                                             Local movements                      34               NaN
#                                                                                                  4338             NaN
#                                                             Total, itinerant and local movements 32               NaN
#                                                                                                  48748            NaN
#          Yukon                                              Itinerant movements                  24300    2016A000260
#                                                             Local movements                      14170    2016A000260
#                                                             Total, itinerant and local movements 38470    2016A000260
#
#                                                                                                          Rank and number of movements  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18                 Rank of movements
#                                                                                                  56769            Number of movements
#                                                             Local movements                      5                  Rank of movements
#                                                                                                  79369            Number of movements
#                                                             Total, itinerant and local movements 12                 Rank of movements
#                                                                                                  136138           Number of movements
#          Alberta                                            Itinerant movements                  452402           Number of movements
#                                                             Local movements                      175239           Number of movements
#                                                             Total, itinerant and local movements 627641           Number of movements
#          Boundary Bay, British Columbia                     Itinerant movements                  14                 Rank of movements
#                                                                                                  68630            Number of movements
#                                                             Local movements                      1                  Rank of movements
#                                                                                                  139509           Number of movements
#                                                             Total, itinerant and local movements 4                  Rank of movements
#                                                                                                  208139           Number of movements
#          British Columbia                                   Itinerant movements                  784723           Number of movements
#                                                             Local movements                      443831           Number of movements
#                                                             Total, itinerant and local movements 1228554          Number of movements
#          Calgary International, Alberta                     Itinerant movements                  3                  Rank of movements
#                                                                                                  224561           Number of movements
#                                                             Local movements                      37                 Rank of movements
#                                                                                                  14397            Number of movements
#                                                             Total, itinerant and local movements 3                  Rank of movements
#                                                                                                  238958           Number of movements
#          Calgary/Springbank, Alberta                        Itinerant movements                  27                 Rank of movements
#                                                                                                  41491            Number of movements
#                                                             Local movements                      3                  Rank of movements
#                                                                                                  87107            Number of movements
#                                                             Total, itinerant and local movements 13                 Rank of movements
#                                                                                                  128598           Number of movements
# ...                                                                                                                               ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170            Number of movements
#                                                             Total, itinerant and local movements 40                 Rank of movements
#                                                                                                  38470            Number of movements
#          Windsor, Ontario                                   Itinerant movements                  40                 Rank of movements
#                                                                                                  23003            Number of movements
#                                                             Local movements                      24                 Rank of movements
#                                                                                                  19697            Number of movements
#                                                             Total, itinerant and local movements 36                 Rank of movements
#                                                                                                  42700            Number of movements
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7                  Rank of movements
#                                                                                                  109314           Number of movements
#                                                             Local movements                      30                 Rank of movements
#                                                                                                  9038             Number of movements
#                                                             Total, itinerant and local movements 15                 Rank of movements
#                                                                                                  118352           Number of movements
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26                 Rank of movements
#                                                                                                  42769            Number of movements
#                                                             Local movements                      5                  Rank of movements
#                                                                                                  75236            Number of movements
#                                                             Total, itinerant and local movements 16                 Rank of movements
#                                                                                                  118005           Number of movements
#          Yellowknife, Northwest Territories                 Itinerant movements                  25                 Rank of movements
#                                                                                                  44410            Number of movements
#                                                             Local movements                      34                 Rank of movements
#                                                                                                  4338             Number of movements
#                                                             Total, itinerant and local movements 32                 Rank of movements
#                                                                                                  48748            Number of movements
#          Yukon                                              Itinerant movements                  24300            Number of movements
#                                                             Local movements                      14170            Number of movements
#                                                             Total, itinerant and local movements 38470            Number of movements
#
#                                                                                                              UOM  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18       Number
#                                                                                                  56769    Number
#                                                             Local movements                      5        Number
#                                                                                                  79369    Number
#                                                             Total, itinerant and local movements 12       Number
#                                                                                                  136138   Number
#          Alberta                                            Itinerant movements                  452402   Number
#                                                             Local movements                      175239   Number
#                                                             Total, itinerant and local movements 627641   Number
#          Boundary Bay, British Columbia                     Itinerant movements                  14       Number
#                                                                                                  68630    Number
#                                                             Local movements                      1        Number
#                                                                                                  139509   Number
#                                                             Total, itinerant and local movements 4        Number
#                                                                                                  208139   Number
#          British Columbia                                   Itinerant movements                  784723   Number
#                                                             Local movements                      443831   Number
#                                                             Total, itinerant and local movements 1228554  Number
#          Calgary International, Alberta                     Itinerant movements                  3        Number
#                                                                                                  224561   Number
#                                                             Local movements                      37       Number
#                                                                                                  14397    Number
#                                                             Total, itinerant and local movements 3        Number
#                                                                                                  238958   Number
#          Calgary/Springbank, Alberta                        Itinerant movements                  27       Number
#                                                                                                  41491    Number
#                                                             Local movements                      3        Number
#                                                                                                  87107    Number
#                                                             Total, itinerant and local movements 13       Number
#                                                                                                  128598   Number
# ...                                                                                                          ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170    Number
#                                                             Total, itinerant and local movements 40       Number
#                                                                                                  38470    Number
#          Windsor, Ontario                                   Itinerant movements                  40       Number
#                                                                                                  23003    Number
#                                                             Local movements                      24       Number
#                                                                                                  19697    Number
#                                                             Total, itinerant and local movements 36       Number
#                                                                                                  42700    Number
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7        Number
#                                                                                                  109314   Number
#                                                             Local movements                      30       Number
#                                                                                                  9038     Number
#                                                             Total, itinerant and local movements 15       Number
#                                                                                                  118352   Number
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26       Number
#                                                                                                  42769    Number
#                                                             Local movements                      5        Number
#                                                                                                  75236    Number
#                                                             Total, itinerant and local movements 16       Number
#                                                                                                  118005   Number
#          Yellowknife, Northwest Territories                 Itinerant movements                  25       Number
#                                                                                                  44410    Number
#                                                             Local movements                      34       Number
#                                                                                                  4338     Number
#                                                             Total, itinerant and local movements 32       Number
#                                                                                                  48748    Number
#          Yukon                                              Itinerant movements                  24300    Number
#                                                             Local movements                      14170    Number
#                                                             Total, itinerant and local movements 38470    Number
#
#                                                                                                           UOM_ID  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18          223
#                                                                                                  56769       223
#                                                             Local movements                      5           223
#                                                                                                  79369       223
#                                                             Total, itinerant and local movements 12          223
#                                                                                                  136138      223
#          Alberta                                            Itinerant movements                  452402      223
#                                                             Local movements                      175239      223
#                                                             Total, itinerant and local movements 627641      223
#          Boundary Bay, British Columbia                     Itinerant movements                  14          223
#                                                                                                  68630       223
#                                                             Local movements                      1           223
#                                                                                                  139509      223
#                                                             Total, itinerant and local movements 4           223
#                                                                                                  208139      223
#          British Columbia                                   Itinerant movements                  784723      223
#                                                             Local movements                      443831      223
#                                                             Total, itinerant and local movements 1228554     223
#          Calgary International, Alberta                     Itinerant movements                  3           223
#                                                                                                  224561      223
#                                                             Local movements                      37          223
#                                                                                                  14397       223
#                                                             Total, itinerant and local movements 3           223
#                                                                                                  238958      223
#          Calgary/Springbank, Alberta                        Itinerant movements                  27          223
#                                                                                                  41491       223
#                                                             Local movements                      3           223
#                                                                                                  87107       223
#                                                             Total, itinerant and local movements 13          223
#                                                                                                  128598      223
# ...                                                                                                          ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170       223
#                                                             Total, itinerant and local movements 40          223
#                                                                                                  38470       223
#          Windsor, Ontario                                   Itinerant movements                  40          223
#                                                                                                  23003       223
#                                                             Local movements                      24          223
#                                                                                                  19697       223
#                                                             Total, itinerant and local movements 36          223
#                                                                                                  42700       223
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7           223
#                                                                                                  109314      223
#                                                             Local movements                      30          223
#                                                                                                  9038        223
#                                                             Total, itinerant and local movements 15          223
#                                                                                                  118352      223
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26          223
#                                                                                                  42769       223
#                                                             Local movements                      5           223
#                                                                                                  75236       223
#                                                             Total, itinerant and local movements 16          223
#                                                                                                  118005      223
#          Yellowknife, Northwest Territories                 Itinerant movements                  25          223
#                                                                                                  44410       223
#                                                             Local movements                      34          223
#                                                                                                  4338        223
#                                                             Total, itinerant and local movements 32          223
#                                                                                                  48748       223
#          Yukon                                              Itinerant movements                  24300       223
#                                                             Local movements                      14170       223
#                                                             Total, itinerant and local movements 38470       223
#
#                                                                                                          SCALAR_FACTOR  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18             units
#                                                                                                  56769          units
#                                                             Local movements                      5              units
#                                                                                                  79369          units
#                                                             Total, itinerant and local movements 12             units
#                                                                                                  136138         units
#          Alberta                                            Itinerant movements                  452402         units
#                                                             Local movements                      175239         units
#                                                             Total, itinerant and local movements 627641         units
#          Boundary Bay, British Columbia                     Itinerant movements                  14             units
#                                                                                                  68630          units
#                                                             Local movements                      1              units
#                                                                                                  139509         units
#                                                             Total, itinerant and local movements 4              units
#                                                                                                  208139         units
#          British Columbia                                   Itinerant movements                  784723         units
#                                                             Local movements                      443831         units
#                                                             Total, itinerant and local movements 1228554        units
#          Calgary International, Alberta                     Itinerant movements                  3              units
#                                                                                                  224561         units
#                                                             Local movements                      37             units
#                                                                                                  14397          units
#                                                             Total, itinerant and local movements 3              units
#                                                                                                  238958         units
#          Calgary/Springbank, Alberta                        Itinerant movements                  27             units
#                                                                                                  41491          units
#                                                             Local movements                      3              units
#                                                                                                  87107          units
#                                                             Total, itinerant and local movements 13             units
#                                                                                                  128598         units
# ...                                                                                                                ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170          units
#                                                             Total, itinerant and local movements 40             units
#                                                                                                  38470          units
#          Windsor, Ontario                                   Itinerant movements                  40             units
#                                                                                                  23003          units
#                                                             Local movements                      24             units
#                                                                                                  19697          units
#                                                             Total, itinerant and local movements 36             units
#                                                                                                  42700          units
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7              units
#                                                                                                  109314         units
#                                                             Local movements                      30             units
#                                                                                                  9038           units
#                                                             Total, itinerant and local movements 15             units
#                                                                                                  118352         units
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26             units
#                                                                                                  42769          units
#                                                             Local movements                      5              units
#                                                                                                  75236          units
#                                                             Total, itinerant and local movements 16             units
#                                                                                                  118005         units
#          Yellowknife, Northwest Territories                 Itinerant movements                  25             units
#                                                                                                  44410          units
#                                                             Local movements                      34             units
#                                                                                                  4338           units
#                                                             Total, itinerant and local movements 32             units
#                                                                                                  48748          units
#          Yukon                                              Itinerant movements                  24300          units
#                                                             Local movements                      14170          units
#                                                             Total, itinerant and local movements 38470          units
#
#                                                                                                           SCALAR_ID  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18               0
#                                                                                                  56769            0
#                                                             Local movements                      5                0
#                                                                                                  79369            0
#                                                             Total, itinerant and local movements 12               0
#                                                                                                  136138           0
#          Alberta                                            Itinerant movements                  452402           0
#                                                             Local movements                      175239           0
#                                                             Total, itinerant and local movements 627641           0
#          Boundary Bay, British Columbia                     Itinerant movements                  14               0
#                                                                                                  68630            0
#                                                             Local movements                      1                0
#                                                                                                  139509           0
#                                                             Total, itinerant and local movements 4                0
#                                                                                                  208139           0
#          British Columbia                                   Itinerant movements                  784723           0
#                                                             Local movements                      443831           0
#                                                             Total, itinerant and local movements 1228554          0
#          Calgary International, Alberta                     Itinerant movements                  3                0
#                                                                                                  224561           0
#                                                             Local movements                      37               0
#                                                                                                  14397            0
#                                                             Total, itinerant and local movements 3                0
#                                                                                                  238958           0
#          Calgary/Springbank, Alberta                        Itinerant movements                  27               0
#                                                                                                  41491            0
#                                                             Local movements                      3                0
#                                                                                                  87107            0
#                                                             Total, itinerant and local movements 13               0
#                                                                                                  128598           0
# ...                                                                                                             ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170            0
#                                                             Total, itinerant and local movements 40               0
#                                                                                                  38470            0
#          Windsor, Ontario                                   Itinerant movements                  40               0
#                                                                                                  23003            0
#                                                             Local movements                      24               0
#                                                                                                  19697            0
#                                                             Total, itinerant and local movements 36               0
#                                                                                                  42700            0
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7                0
#                                                                                                  109314           0
#                                                             Local movements                      30               0
#                                                                                                  9038             0
#                                                             Total, itinerant and local movements 15               0
#                                                                                                  118352           0
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26               0
#                                                                                                  42769            0
#                                                             Local movements                      5                0
#                                                                                                  75236            0
#                                                             Total, itinerant and local movements 16               0
#                                                                                                  118005           0
#          Yellowknife, Northwest Territories                 Itinerant movements                  25               0
#                                                                                                  44410            0
#                                                             Local movements                      34               0
#                                                                                                  4338             0
#                                                             Total, itinerant and local movements 32               0
#                                                                                                  48748            0
#          Yukon                                              Itinerant movements                  24300            0
#                                                             Local movements                      14170            0
#                                                             Total, itinerant and local movements 38470            0
#
#                                                                                                              VECTOR  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18       v41501710
#                                                                                                  56769    v41501711
#                                                             Local movements                      5        v41501712
#                                                                                                  79369    v41501713
#                                                             Total, itinerant and local movements 12       v41501708
#                                                                                                  136138   v41501709
#          Alberta                                            Itinerant movements                  452402   v44207283
#                                                             Local movements                      175239   v44207284
#                                                             Total, itinerant and local movements 627641   v44207282
#          Boundary Bay, British Columbia                     Itinerant movements                  14       v41501716
#                                                                                                  68630    v41501717
#                                                             Local movements                      1        v41501718
#                                                                                                  139509   v41501719
#                                                             Total, itinerant and local movements 4        v41501714
# ...
#          Yellowknife, Northwest Territories                 Itinerant movements                  25          NaN
#                                                                                                  44410       NaN
#                                                             Local movements                      34          NaN
#                                                                                                  4338        NaN
#                                                             Total, itinerant and local movements 32          NaN
#                                                                                                  48748       NaN
#          Yukon                                              Itinerant movements                  24300       NaN
#                                                             Local movements                      14170       NaN
#                                                             Total, itinerant and local movements 38470       NaN
#
#                                                                                                          TERMINATED  \
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18             NaN
#                                                                                                  56769          NaN
#                                                             Local movements                      5              NaN
#                                                                                                  79369          NaN
#                                                             Total, itinerant and local movements 12             NaN
#                                                                                                  136138         NaN
#          Alberta                                            Itinerant movements                  452402         NaN
#                                                             Local movements                      175239         NaN
#                                                             Total, itinerant and local movements 627641         NaN
#          Boundary Bay, British Columbia                     Itinerant movements                  14             NaN
#                                                                                                  68630          NaN
#                                                             Local movements                      1              NaN
#                                                                                                  139509         NaN
#                                                             Total, itinerant and local movements 4              NaN
#                                                                                                  208139         NaN
#          British Columbia                                   Itinerant movements                  784723         NaN
#                                                             Local movements                      443831         NaN
#                                                             Total, itinerant and local movements 1228554        NaN
#          Calgary International, Alberta                     Itinerant movements                  3              NaN
#                                                                                                  224561         NaN
#                                                             Local movements                      37             NaN
#                                                                                                  14397          NaN
#                                                             Total, itinerant and local movements 3              NaN
#                                                                                                  238958         NaN
#          Calgary/Springbank, Alberta                        Itinerant movements                  27             NaN
#                                                                                                  41491          NaN
#                                                             Local movements                      3              NaN
#                                                                                                  87107          NaN
#                                                             Total, itinerant and local movements 13             NaN
#                                                                                                  128598         NaN
# ...                                                                                                             ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170          NaN
#                                                             Total, itinerant and local movements 40             NaN
#                                                                                                  38470          NaN
#          Windsor, Ontario                                   Itinerant movements                  40             NaN
#                                                                                                  23003          NaN
#                                                             Local movements                      24             NaN
#                                                                                                  19697          NaN
#                                                             Total, itinerant and local movements 36             NaN
#                                                                                                  42700          NaN
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7              NaN
#                                                                                                  109314         NaN
#                                                             Local movements                      30             NaN
#                                                                                                  9038           NaN
#                                                             Total, itinerant and local movements 15             NaN
#                                                                                                  118352         NaN
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26             NaN
#                                                                                                  42769          NaN
#                                                             Local movements                      5              NaN
#                                                                                                  75236          NaN
#                                                             Total, itinerant and local movements 16             NaN
#                                                                                                  118005         NaN
#          Yellowknife, Northwest Territories                 Itinerant movements                  25             NaN
#                                                                                                  44410          NaN
#                                                             Local movements                      34             NaN
#                                                                                                  4338           NaN
#                                                             Total, itinerant and local movements 32             NaN
#                                                                                                  48748          NaN
#          Yukon                                              Itinerant movements                  24300          NaN
#                                                             Local movements                      14170          NaN
#                                                             Total, itinerant and local movements 38470          NaN
#
#                                                                                                           DECIMALS
# REF_DATE GEO                                                Class of operation                   VALUE
# 1997     Abbotsford, British Columbia                       Itinerant movements                  18              0
#                                                                                                  56769           0
#                                                             Local movements                      5               0
#                                                                                                  79369           0
#                                                             Total, itinerant and local movements 12              0
#                                                                                                  136138          0
#          Alberta                                            Itinerant movements                  452402          0
#                                                             Local movements                      175239          0
#                                                             Total, itinerant and local movements 627641          0
#          Boundary Bay, British Columbia                     Itinerant movements                  14              0
#                                                                                                  68630           0
#                                                             Local movements                      1               0
#                                                                                                  139509          0
#                                                             Total, itinerant and local movements 4               0
#                                                                                                  208139          0
#          British Columbia                                   Itinerant movements                  784723          0
#                                                             Local movements                      443831          0
#                                                             Total, itinerant and local movements 1228554         0
#          Calgary International, Alberta                     Itinerant movements                  3               0
#                                                                                                  224561          0
#                                                             Local movements                      37              0
#                                                                                                  14397           0
#                                                             Total, itinerant and local movements 3               0
#                                                                                                  238958          0
#          Calgary/Springbank, Alberta                        Itinerant movements                  27              0
#                                                                                                  41491           0
#                                                             Local movements                      3               0
#                                                                                                  87107           0
#                                                             Total, itinerant and local movements 13              0
#                                                                                                  128598          0
# ...                                                                                                            ...
# 2018     Whitehorse International, Yukon                    Local movements                      14170           0
#                                                             Total, itinerant and local movements 40              0
#                                                                                                  38470           0
#          Windsor, Ontario                                   Itinerant movements                  40              0
#                                                                                                  23003           0
#                                                             Local movements                      24              0
#                                                                                                  19697           0
#                                                             Total, itinerant and local movements 36              0
#                                                                                                  42700           0
#          Winnipeg/James Armstrong Richardson Internation... Itinerant movements                  7               0
#                                                                                                  109314          0
#                                                             Local movements                      30              0
#                                                                                                  9038            0
#                                                             Total, itinerant and local movements 15              0
#                                                                                                  118352          0
#          Winnipeg/St. Andrews, Manitoba                     Itinerant movements                  26              0
#                                                                                                  42769           0
#                                                             Local movements                      5               0
#                                                                                                  75236           0
#                                                             Total, itinerant and local movements 16              0
#                                                                                                  118005          0
#          Yellowknife, Northwest Territories                 Itinerant movements                  25              0
#                                                                                                  44410           0
#                                                             Local movements                      34              0
#                                                                                                  4338            0
#                                                             Total, itinerant and local movements 32              0
#                                                                                                  48748           0
#          Yukon                                              Itinerant movements                  24300           0
#                                                             Local movements                      14170           0
#                                                             Total, itinerant and local movements 38470           0
#
# [6330 rows x 12 columns]

# %%
# mov = (dfo[dfo['REF_DATE'].notnull() & (dfo['GEO']=='Total Canadian Airports') &
#     (dfo['Class of operation']=='Total, itinerant and local movements')]), (dfo['VALUE'])

mov = (dfo[dfo['REF_DATE'].notnull() & (dfo['GEO']=='Total Canadian Airports') &
    (dfo['Class of operation']=='Total, itinerant and local movements')]), (dfo['REF_DATE'], dfo['VALUE'])
           
print (mov)
# Out:
# (Empty DataFrame
# Columns: [REF_DATE, GEO, DGUID, Class of operation, Rank and number of movements, UOM, UOM_ID, SCALAR_FACTOR, SCALAR_ID, VECTOR, COORDINATE, VALUE, STATUS, SYMBOL, TERMINATED, DECIMALS]
# Index: [], (0       1997
# 1       1997
# 2       1997
# 3       1997
# 4       1997
# 5       1997
# 6       1997
# 7       1997
# 8       1997
# 9       1997
# 10      1997
# 11      1997
# 12      1997
# 13      1997
# 14      1997
# 15      1997
# 16      1997
# 17      1997
# 18      1997
# 19      1997
# 20      1997
# 21      1997
# 22      1997
# 23      1997
# 24      1997
# 25      1997
# 26      1997
# 27      1997
# 28      1997
# 29      1997
#         ...
# 6330    2018
# 6331    2018
# 6332    2018
# 6333    2018
# 6334    2018
# 6335    2018
# 6336    2018
# 6337    2018
# 6338    2018
# 6339    2018
# 6340    2018
# 6341    2018
# 6342    2018
# 6343    2018
# 6344    2018
# 6345    2018
# 6346    2018
# 6347    2018
# 6348    2018
# 6349    2018
# 6350    2018
# 6351    2018
# 6352    2018
# 6353    2018
# 6354    2018
# 6355    2018
# 6356    2018
# 6357    2018
# 6358    2018
# 6359    2018
# Name: REF_DATE, Length: 6360, dtype: int64, 0       4997067
# 1       3313762
# 2       1683305
# 3        128808
# 4         83026
# 5         45782
# 6            39
# 7         53097
# 8            31
# 9         35395
# 10           34
# 11        17702
# 12           27
# 13        75711
# 14           23
# 15        47631
# 16           23
# 17        28080
# 18       167569
# 19       101962
# 20        65607
# 21            9
# 22       167569
# 23            9
# 24       101962
# 25            7
# 26        65607
# 27        79670
# 28        46550
# 29        33120
#          ...
# 6330          2
# 6331     339441
# 6332          2
# 6333     338575
# 6334         39
# 6335        866
# 6336         13
# 6337     123141
# 6338          9
# 6339      86547
# 6340         15
# 6341      36594
# 6342      38470
# 6343      24300
# 6344      14170
# 6345         40
# 6346      38470
# 6347         37
# 6348      24300
# 6349         28
# 6350      14170
# 6351      48748
# 6352      44410
# 6353       4338
# 6354         32
# 6355      48748
# 6356         25
# 6357      44410
# 6358         34
# 6359       4338
# Name: VALUE, Length: 6360, dtype: int64))

# %%
dfm.shape
# Out:
# (181464, 452)

# %%
dfm.head()
# Out:
#     OccID   OccNo_x  AirportID AirportID_AirportName  AirportID_CountryID  \
# 0  152828  A19P0071     1984.0     Erik Nielsen Intl                  2.0
# 1  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 2  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 3  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
# 4  152827  A19W0070     1984.0     Erik Nielsen Intl                  2.0
#
#   AirportID_CountryID_DisplayEng AirportID_CountryID_DisplayFre  \
# 0                         CANADA                         CANADA
# 1                         CANADA                         CANADA
# 2                         CANADA                         CANADA
# 3                         CANADA                         CANADA
# 4                         CANADA                         CANADA
#
#    Airport_ProvinceID AirportID_ProvinceID_DisplayEng  \
# 0                24.0                           YUKON
# 1                24.0                           YUKON
# 2                24.0                           YUKON
# 3                24.0                           YUKON
# 4                24.0                           YUKON
#
#   AirportID_ProvinceID_DisplayFre  \
# 0                           YUKON
# 1                           YUKON
# 2                           YUKON
# 3                           YUKON
# 4                           YUKON
#
#                          ...                         EventPhaseSequence  \
# 0                        ...                                          1
# 1                        ...                                          1
# 2                        ...                                          2
# 3                        ...                                          3
# 4                        ...                                          4
#
#                                  EventID_DisplayEng  \
# 0  Flight crew incapacitation/illness/medical issue
# 1                           Smoke - Passenger cabin
# 2                                   Smoke - Cockpit
# 3                                       Smoke - APU
# 4          Declared Emergency/Priority/ARFF Standby
#
#                              EventID_DisplayFre  \
# 0  Maladie/Incapacité de l'équipage de conduite
# 1                      Fumée - Cabine passagers
# 2                     Fumée - Poste de pilotage
# 3                                   Fumée - APU
# 4                     Déclaration d'une urgence
#
#                                     FullEventDescEng  \
# 0  [Aircraft operation general].[Flight crew].[Fl...
# 1  [Aircraft/system/component related event (Airc...
# 2  [Aircraft/system/component related event (Airc...
# 3  [Aircraft/system/component related event (Airc...
# 4  [Consequential events].[Declared Emergency/Pri...
#
#                                     FullEventDescFre  PhaseID  \
# 0  [Exploitation de l'aéronef - général].[Équipag...    184.0
# 1  [Evénement aéronef/système/composant (Aéronef/...    211.0
# 2  [Evénement aéronef/système/composant (Aéronef/...    211.0
# 3  [Evénement aéronef/système/composant (Aéronef/...    211.0
# 4  [Evénements résultants, conséquences].[Déclara...    211.0
#
#                PhaseID_DisplayEng           PhaseID_DisplayFre  \
# 0                          Cruise                    Croisière
# 1  Standing : Engine(s) Shut Down  Stationné - arrêt du moteur
# 2  Standing : Engine(s) Shut Down  Stationné - arrêt du moteur
# 3  Standing : Engine(s) Shut Down  Stationné - arrêt du moteur
# 4  Standing : Engine(s) Shut Down  Stationné - arrêt du moteur
#
#                                     FullPhaseDescEng  \
# 0  [POWERED FIXED-WING AIRCRAFT].[En-route].[Cruise]
# 1  [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 2  [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 3  [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
# 4  [POWERED FIXED-WING AIRCRAFT].[Standing].[Stan...
#
#                                     FullPhaseDescFre
# 0  [Aéronef à voilure fixe - motorisé].[En route]...
# 1  [Aéronef à voilure fixe - motorisé].[Stationne...
# 2  [Aéronef à voilure fixe - motorisé].[Stationne...
# 3  [Aéronef à voilure fixe - motorisé].[Stationne...
# 4  [Aéronef à voilure fixe - motorisé].[Stationne...
#
# [5 rows x 452 columns]

# %%
dfm = dfm.sort_values("OccID", ascending=True)
dfm = dfm.drop_duplicates(subset ="OccID") 
#df.dropna(inplace = True)

# %%
#msno.matrix(dfm_)

# %%
dfm.shape
# Out:
# (43814, 452)

# %%
# dfm.Latitude.fillna(0, inplace=True)
# dfm.Longitude.fillna(0, inplace=True) Removed to avoid noise/bias

# %%
dfm.isnull().sum()
#dropped the nulls and update the dataframe
# dfm.shape
# Out:
# OccID                                      0
# OccNo_x                                    0
# AirportID                              26500
# AirportID_AirportName                  26500
# AirportID_CountryID                    26500
# AirportID_CountryID_DisplayEng         26500
# AirportID_CountryID_DisplayFre         26500
# Airport_ProvinceID                     26920
# AirportID_ProvinceID_DisplayEng        26920
# AirportID_ProvinceID_DisplayFre        26920
# Location                               26500
# Latitude                                1330
# LatEnum                                 1332
# LatEnum_DisplayEng                      1332
# LatEnum_DisplayFre                      1332
# Longitude                               1326
# LongEnum                                1517
# LongEnum_DisplayEng                     1517
# LongEnum_DisplayFre                     1517
# ICAO                                   26500
# BearingID                              41378
# BearingID_Abbr                         41378
# BearingID_CompassPoint                 41378
# BearingID_Highest                      41378
# BearingID_Lowest                       41378
# BearingID_Middle                       41378
# CountryID                                  0
# CountryID_DisplayEng                       0
# CountryID_DisplayFre                       0
# Distance                               41377
#                                        ...
# OtherAircraftSightedEnum_DisplayEng    43690
# OtherAircraftSightedEnum_DisplayFre    43690
# ReqSepHorizontal                       43670
# ReqSepHorizontalEnum                   43494
# ReqSepHorizontalEnum_DisplayEng        43494
# ReqSepHorizontalEnum_DisplayFre        43494
# ReqSepVertical                         43704
# ReqSepTime                             43812
# ActualSepHorizontal                    43654
# ActualSepHorizontalEnum                43494
# ActualSepHorizontalEnum_DisplayEng     43494
# ActualSepHorizontalEnum_DisplayFre     43494
# ActualSepVertical                      43711
# ActualSepTime                          43813
# AtsUnitInvolvedEnum                    42132
# AtsUnitInvolvedEnum_DisplayEng         42132
# AtsUnitInvolvedEnum_DisplayFre         42132
# OccNo                                      0
# AcID_y                                     0
# EventID                                    0
# EventPhaseSequence                         0
# EventID_DisplayEng                       275
# EventID_DisplayFre                       275
# FullEventDescEng                         275
# FullEventDescFre                         524
# PhaseID                                  389
# PhaseID_DisplayEng                       389
# PhaseID_DisplayFre                       389
# FullPhaseDescEng                         389
# FullPhaseDescFre                         389
# Length: 452, dtype: int64

# %%
dfm.shape
# Out:
# (43814, 452)

# %%
dfm.dtypes
# Out:
# OccID                                    int64
# OccNo_x                                 object
# AirportID                              float64
# AirportID_AirportName                   object
# AirportID_CountryID                    float64
# AirportID_CountryID_DisplayEng          object
# AirportID_CountryID_DisplayFre          object
# Airport_ProvinceID                     float64
# AirportID_ProvinceID_DisplayEng         object
# AirportID_ProvinceID_DisplayFre         object
# Location                                object
# Latitude                               float64
# LatEnum                                float64
# LatEnum_DisplayEng                      object
# LatEnum_DisplayFre                      object
# Longitude                              float64
# LongEnum                               float64
# LongEnum_DisplayEng                     object
# LongEnum_DisplayFre                     object
# ICAO                                    object
# BearingID                              float64
# BearingID_Abbr                          object
# BearingID_CompassPoint                  object
# BearingID_Highest                      float64
# BearingID_Lowest                       float64
# BearingID_Middle                       float64
# CountryID                                int64
# CountryID_DisplayEng                    object
# CountryID_DisplayFre                    object
# Distance                               float64
#                                         ...
# OtherAircraftSightedEnum_DisplayEng     object
# OtherAircraftSightedEnum_DisplayFre     object
# ReqSepHorizontal                       float64
# ReqSepHorizontalEnum                   float64
# ReqSepHorizontalEnum_DisplayEng         object
# ReqSepHorizontalEnum_DisplayFre         object
# ReqSepVertical                         float64
# ReqSepTime                             float64
# ActualSepHorizontal                    float64
# ActualSepHorizontalEnum                float64
# ActualSepHorizontalEnum_DisplayEng      object
# ActualSepHorizontalEnum_DisplayFre      object
# ActualSepVertical                      float64
# ActualSepTime                          float64
# AtsUnitInvolvedEnum                    float64
# AtsUnitInvolvedEnum_DisplayEng          object
# AtsUnitInvolvedEnum_DisplayFre          object
# OccNo                                   object
# AcID_y                                 float64
# EventID                                  int64
# EventPhaseSequence                       int64
# EventID_DisplayEng                      object
# EventID_DisplayFre                      object
# FullEventDescEng                        object
# FullEventDescFre                        object
# PhaseID                                float64
# PhaseID_DisplayEng                      object
# PhaseID_DisplayFre                      object
# FullPhaseDescEng                        object
# FullPhaseDescFre                        object
# Length: 452, dtype: object

# %%
# dfp = dfm.drop(dfm.columns[dfm.apply(lambda col: col.isnull().sum() > 300)], axis=1)

# %%
# dfp.shape

# %%
# msno.matrix(dfp)

# %%
# dfp.columns

# %%
dfm.columns
# Out:
# Index(['OccID', 'OccNo_x', 'AirportID', 'AirportID_AirportName',
#        'AirportID_CountryID', 'AirportID_CountryID_DisplayEng',
#        'AirportID_CountryID_DisplayFre', 'Airport_ProvinceID',
#        'AirportID_ProvinceID_DisplayEng', 'AirportID_ProvinceID_DisplayFre',
#        ...
#        'EventPhaseSequence', 'EventID_DisplayEng', 'EventID_DisplayFre',
#        'FullEventDescEng', 'FullEventDescFre', 'PhaseID', 'PhaseID_DisplayEng',
#        'PhaseID_DisplayFre', 'FullPhaseDescEng', 'FullPhaseDescFre'],
#       dtype='object', length=452)

# %%
# import labelencoder
from sklearn.preprocessing import LabelEncoder

# %%
dfm.OccDate
# Out:
# 181463     1/9/1976 12:00:00 AM
# 181461    1/19/1976 12:00:00 AM
# 181460    2/13/1976 12:00:00 AM
# 181455    2/16/1976 12:00:00 AM
# 181453    2/25/1976 12:00:00 AM
# 181450     3/4/1976 12:00:00 AM
# 181448     5/5/1976 12:00:00 AM
# 181446    5/29/1976 12:00:00 AM
# 181444     6/4/1976 12:00:00 AM
# 181443     6/5/1976 12:00:00 AM
# 181442     6/6/1976 12:00:00 AM
# 181441     6/5/1976 12:00:00 AM
# 181440    5/24/1976 12:00:00 AM
# 181438    6/19/1976 12:00:00 AM
# 181437    6/27/1976 12:00:00 AM
# 181435    7/18/1976 12:00:00 AM
# 181434    7/19/1976 12:00:00 AM
# 181431    7/22/1976 12:00:00 AM
# 181430    7/29/1976 12:00:00 AM
# 181429    7/31/1976 12:00:00 AM
# 181428     8/8/1976 12:00:00 AM
# 181427    8/12/1976 12:00:00 AM
# 181426    8/13/1976 12:00:00 AM
# 181424    8/16/1976 12:00:00 AM
# 181423    8/22/1976 12:00:00 AM
# 181421    9/13/1976 12:00:00 AM
# 181420    9/14/1976 12:00:00 AM
# 181419    9/18/1976 12:00:00 AM
# 181417    9/19/1976 12:00:00 AM
# 181415    9/23/1976 12:00:00 AM
#                   ...
# 160       5/13/2019 12:00:00 AM
# 150       5/24/2019 12:00:00 AM
# 149        6/5/2019 12:00:00 AM
# 145       5/27/2019 12:00:00 AM
# 139       5/29/2019 12:00:00 AM
# 137        6/4/2019 12:00:00 AM
# 123       5/31/2019 12:00:00 AM
# 120        6/5/2019 12:00:00 AM
# 116       5/25/2019 12:00:00 AM
# 108       5/19/2019 12:00:00 AM
# 106        6/6/2019 12:00:00 AM
# 100        6/7/2019 12:00:00 AM
# 75         6/8/2019 12:00:00 AM
# 57         6/7/2019 12:00:00 AM
# 52         6/9/2019 12:00:00 AM
# 51        5/17/2019 12:00:00 AM
# 45         6/9/2019 12:00:00 AM
# 37         6/4/2019 12:00:00 AM
# 35         6/9/2019 12:00:00 AM
# 29         6/5/2019 12:00:00 AM
# 26        6/11/2019 12:00:00 AM
# 22        6/11/2019 12:00:00 AM
# 19         6/7/2019 12:00:00 AM
# 18        6/12/2019 12:00:00 AM
# 16         6/9/2019 12:00:00 AM
# 15        6/11/2019 12:00:00 AM
# 14        6/12/2019 12:00:00 AM
# 11        5/24/2019 12:00:00 AM
# 1         6/12/2019 12:00:00 AM
# 0         6/11/2019 12:00:00 AM
# Name: OccDate, Length: 43814, dtype: object

# %%
dfm['OccDate'] = dfm['OccDate'].astype(str)

# %%
dfm['OccDate'] = pd.to_datetime(dfm['OccDate'])

# %%
# dfm.OccDate.dt.year

# %%
# dfm['OccDate'] = le.fit_transform(dfm['OccDate'].astype(str))

# %%
dfm.shape
# Out:
# (43814, 452)

# %%
dfm.columns
# Out:
# Index(['OccID', 'OccNo_x', 'AirportID', 'AirportID_AirportName',
#        'AirportID_CountryID', 'AirportID_CountryID_DisplayEng',
#        'AirportID_CountryID_DisplayFre', 'Airport_ProvinceID',
#        'AirportID_ProvinceID_DisplayEng', 'AirportID_ProvinceID_DisplayFre',
#        ...
#        'EventPhaseSequence', 'EventID_DisplayEng', 'EventID_DisplayFre',
#        'FullEventDescEng', 'FullEventDescFre', 'PhaseID', 'PhaseID_DisplayEng',
#        'PhaseID_DisplayFre', 'FullPhaseDescEng', 'FullPhaseDescFre'],
#       dtype='object', length=452)

# %%
dfm.duplicated(subset=None, keep="first").sum()
#found two duplicates
dfm.shape
# Out:
# (43814, 452)

# %% [markdown]
# ### Visualization

# %%
#importing plotly and cufflinks in offline mode
import plotly as py
import cufflinks as cf
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs
from plotly.offline import init_notebook_mode
from plotly.offline import plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
import geopandas as gp
import matplotlib.pyplot as plt
import descartes
from shapely.geometry import Point, Polygon
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Long = dfm.Longitude * -1

# %%
# colors = dfm

# g = sns.JointGrid('Longitude', "Latitude", colors)
# g = g.plot_marginals(sns.distplot, kde=False, color="grey")
# g.fig.set_size_inches(15,15)

# for OccTypeID, dfm in colors.groupby("OccTypeID"):
#     sns.kdeplot(colors["Longitude"], ax=g.ax_marg_x, legend=False)
#     sns.kdeplot(colors["Latitude"], ax=g.ax_marg_y, vertical=True, legend=False)
#     g.ax_joint.plot(colors["Longitude"], colors["Latitude"], "o", ms=4)
   


#  Test 4, error

# colors = dfm
# g = sns.jointplot("Longitude", "Latitude", data=colors, kind="reg", stat_func=None,
#                   xlim=(0, 60), ylim=(0, 12))


# g.ax_joint.cla() # or g.ax_joint.collections[0].set_visible(False), as per mwaskom's comment

# # set the current axis to be the joint plot's axis
# #plt.sca(g.ax_joint)

# # plt.scatter takes a 'c' keyword for color
# # you can also pass an array of floats and use the 'cmap' keyword to
# # convert them into a colormap
# plt.scatter(dfm.Longitude, dfm.Latitude, c=np.random.random((len(dfm), 3)))

# # Error: Bad colors

# Test 3, error

# colors = np.random.random((len(dfm.OccTypeID),3))
# markers = (['x','o','v','^','<']*100)[:len(dfm.OccTypeID)]

# sns.jointplot(x=dfm.Longitude.values, y=dfm.Latitude.values, data=colors, kind="reg",
#     joint_kws={"color":colors, "marker":markers})
# AttributeError: 'numpy.ndarray' object has no attribute 'get'


# Test 2, error


# event = dfm.OccTypeID

# g = sns.JointGrid(x=dfm.Longitude, y=dfm.Latitude, data=event)
# g = g.plot_joint(plt.scatter, c=np.random.random((len(tips), 3)))
# g = g.plot_marginals(sns.distplot, kde=True, color="k")

# ValueError: cannot reindex from a duplicate axis

# Test 1, working

# sns.jointplot(x=dfm.Longitude.values, y=dfm.Latitude.values, size = 10, cmap='Inferno')
# plt.title('Incidents and Accidents Coordinates')

# %%
can_map0 = gp.read_file('C:/Users/fjbel/Google Drive/RoboG/Aviation Project/TSB_Aviation_Accidents_APR2019/lpr_000b16a_e/lpr_000b16a_e.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:/Users/fjbel/Google Drive/RoboG/Aviation Project/TSB_Aviation_Accidents_APR2019/lpr_000b16a_e/lpr_000b16a_e.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-45-7cce9e6d1574> in <module>
# ----> 1 can_map0 = gp.read_file('C:/Users/fjbel/Google Drive/RoboG/Aviation Project/TSB_Aviation_Accidents_APR2019/lpr_000b16a_e/lpr_000b16a_e.shp')
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      69
#      70     with fiona_env():
# ---> 71         with reader(path_or_bytes, **kwargs) as features:
#      72             crs = features.crs
#      73             if bbox is not None:
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     394     def wrapper(*args, **kwargs):
#     395         if local._env:
# --> 396             return f(*args, **kwargs)
#     397         else:
#     398             if isinstance(args[0], str):
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# C:\ProgramData\Anaconda3\envs\Py36\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: C:/Users/fjbel/Google Drive/RoboG/Aviation Project/TSB_Aviation_Accidents_APR2019/lpr_000b16a_e/lpr_000b16a_e.shp: No such file or directory

# %%
dfm=dfm

# %%
fig, ax = plt.subplots(figsize = (15,15))
can_map0.plot(ax=ax)

# %%
can_map1 = gp.read_file('C:/Users/fjbel/Google Drive/RoboG/Aviation Project/TSB_Aviation_Accidents_APR2019/gpr_000b11a_e/gpr_000b11a_e.shp')

# %%
fig, ax = plt.subplots(figsize = (15,15))
can_map1.plot(ax=ax)

# %%
geometry = [Point(xy) for xy in zip(Long, dfm['Latitude'])]
geometry[:3]

# %%
geo_dfm = gp.GeoDataFrame(dfm, geometry = geometry)
geo_dfm.head

# %%
geo_dfm.crs = {'init':'epsg:4326'}

# %%
geo_dfm.head()

# %%
geo_dfm.plot()

# %%
ax = can_map1.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize = (15,15))
geo_dfm.plot(markersize=5, color='pink', alpha=0.5, ax=ax)
ax.axis('off')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
#from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot

# %%
# data = dict(type = 'cloropleth', locations = ['AZ', 'CA', 'NY'], locationmode = 'USA-states', 
#            colorscale = 'Portland', text = ['text 1', 'text 2', 'text 3'], z = [1.0, 2.0, 3.0],
#            colorbar = {'title': 'Colorbar Title Goes Here'})
# layout = dict(geo = {'scope' : 'usa'})
# choromap = go. Figure(data = [data], layout = layout)
# iplot(choromap)

# %%
#Removed as there are few occurrences before 1976
# dfm.OccDate.dt.year.iplot(kind='histogram', bins=40, theme='white', title='Ocurrences per year')

# %%
# #Drop prior to 1976
# old = dfm[(dfm.OccDate.dt.year < 1976)].index
# dfm.drop(old, inplace=True)

# %%
dfm.OccDate.dt.year.iplot(kind='histogram', bins=50, theme='white', title='Ocurrences per year')

# %%
# plt.figure()          
# N = 5
# menMeans = (20, 35, 30, 35, 27)
# menStd = (2, 3, 4, 1, 2)
# width = 0.35       # the width of the bars
# womenMeans = (25, 32, 34, 20, 25)
# womenStd = (3, 5, 2, 3, 3)    
# ind = np.arange(N)
# plt.ylim(0.0, 65.0)
# plt.bar(ind, menMeans, width, color='r', yerr=menStd, label='Men means')
# plt.bar(ind+width, womenMeans, width, color='y', yerr=womenStd, label='Women means')
# plt.ylabel('Bar plot')      

# x = np.linspace(0, N)
# y = np.sin(x)
# axes2 = plt.twinx()
# axes2.plot(x, y, color='k', label='Sine')
# axes2.set_ylim(-1, 1)
# axes2.set_ylabel('Line plot')

# plt.show()

# %%
# plt.hist(dfm['OccTypeID_DisplayEng'])

# %%
# sns.scatter(x='OccTypeID_DisplayEng', data=df)

# %%
#sns.distplot( a=dfm["OccTypeID"], hist=True, kde=False, rug=False )

#px.bar(df, x='OccTypeID_DisplayEng', template='plotly_white')

px.histogram(dfm, x='OperatorTypeID_DisplayEng', color='OccTypeID_DisplayEng',template='plotly')

# %%
dfm.OccTypeID_DisplayEng.iplot(kind='histogram', bins=50, theme='white', title='Ocurrences per type')

# %%
dfm.PhaseID.fillna(0, inplace=True)

# %%
dfm.PhaseID.isna().sum()

# %%
dfm.PhaseID_DisplayEng=dfm.PhaseID_DisplayEng.astype("str")

# %%
# labels = df.PhaseID
# sizes = df.PhaseID.values
# #explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# plt.show()

# %%
#px.histogram(, x='OrganizationID_DisplayEng', y='OccTypeID_DisplayEng') 
ax = sns.distplot(dfm["PhaseID"])

# %%
dfm['PhaseID_DisplayEng'].value_counts().plot.bar(figsize=(20,20))

# %%
g = sns.FacetGrid(dfm,hue='OccTypeID',palette='Set1',size=6,aspect=2)
g = g.map(plt.hist,'PhaseID',bins=20,alpha=0.5)
plt.legend()

# %%
phases = dfm


for OccTypeID, i in phases.groupby("PhaseID_DisplayEng"):
     sns.kdeplot(phases.PhaseID_DisplayEng[Cruise], ax=g.ax_marg_x, legend=False)
     sns.kdeplot(phases["Initial Climb"], ax=g.ax_marg_y, vertical=True, legend=False)
     g.ax_joint.plot(phases["Cruise"], phases["Initial Climb"], "o", ms=4)

# %%
# g = sns.FacetGrid(dfm,hue='AircraftMakeID',palette='Set1',size=8,aspect=2)
# g = g.map(plt.hist,'TotalFatalCount', bins=20,alpha=0.5)
# plt.legend()

# %%
#dfen.TotalFatalCount

# %%
# dfa.corr('pearson')

# %%
px.scatter(dfm, x='TotalFatalCount', y="OrganizationID_DisplayEng", size='TotalFatalCount', size_max=50)
#Get another graph for <100 fatalities

# %%
plt.scatter(dfm.OccTypeID_DisplayEng, dfm.AircraftMakeID)
#Get another graph for <100 fatalities

# %%
px.scatter_matrix(dfm, dimensions=["PhaseID_DisplayEng",
                                   "AircraftMakeID_DisplayEng"], color = "TotalFatalCount")#"OrganizationID_DisplayEng", "OperatorTypeID_DisplayEng",

# %%
px.scatter(dfm, x="AircraftMakeID_DisplayEng", y="TotalFatalCount", size='TotalFatalCount', size_max=60)

# %% [markdown]
# ### Preprocessing for classification and clustering

# %%
#dfp is a subset of dfm
#dfp.shape, dfm.shape

# %%
# need features that can be used to predict an incident/accident before it actually happens
#thus, can not have features like fatality, damagelevelID etc.
features=['AircraftTypeID','AircraftMakeID','OrganizationID', 'OperationTypeID',
           'OperatorTypeID', 'WeightCategoryID','NumberOfEngine', 
          'MaxTakeOffWeight', 'Latitude','Longitude', 'OccTime',
           'WakeTurbulenceCategoryID', 'DangerousGoodEnum','PhaseID']
target=['OccTypeID']

# %%
df=dfm[features+target]

# %%
df.head()

# %%
df.PhaseID.isna().sum()

# %%
df.shape

# %%
fig, ax = plt.subplots(1, 1, figsize = (12, 6))
sns.heatmap(df.corr(), annot=True, ax = ax, vmin = 0, vmax = 1)

# %% [markdown]
# # Checking for duplicates

# %%
df.duplicated(subset=None, keep="first").sum()
#found two duplicates
df.shape

# %%
col=df.columns
df=df.drop_duplicates(col, keep="first")
df.shape
#Removed the duplicates

# %% [markdown]
# # Find nulls and remove it

# %%
df.isnull().sum().sum()
#gives total number of np.nan in the dataframe

# %%
df=df.dropna()
#dropped the nulls and update the dataframe
df.shape

# %% [markdown]
# # Splitting the dataframe in: (feature,target)

# %%
x=df[features]
y=df[target]

# %%
# Making the target as category
y=y.astype("category")

# TypeCasting the features which are required for our model
x.AircraftTypeID=x.AircraftTypeID.astype("int64")
#x.OccTime=x.OccTime.astype("int64")
x.dtypes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()
x["OrganizationID"]=label_encoder.fit_transform(x["OrganizationID"])
x["AircraftTypeID"]=label_encoder.fit_transform(x["AircraftTypeID"])
x["OccTime"]=label_encoder.fit_transform(x["OccTime"])

# %%
"""temp=[]
for i in label_encoder.fit_transform(x["AircraftTypeID"]):
    if i not in temp:
        temp.append(i)
temp"""

# %%
#Checking if features need some more work or not?
x.head(2)
#x.dtypes

# %%
x.dtypes

# %%
len(x.AircraftMakeID.unique())

# %%
x["AircraftMakeID"]=label_encoder.fit_transform(x["AircraftMakeID"])
_y=y.iloc[:,0].values
clock={}
CLOCK={}
for i, v in enumerate(x["AircraftMakeID"]):
    
    if _y[i]==3:
        if v not in clock.keys():
            clock[v]=1
        elif v in clock.keys():
            clock[v]=clock[v]+1
        else:
            print("weird")
        if v not in CLOCK.keys():
            CLOCK[v]=1
        else:
            CLOCK[v]=CLOCK[v]+1
    else:
        if v not in CLOCK.keys():
            CLOCK[v]=1
        else:
            CLOCK[v]=CLOCK[v]+1

            
        #print(v, _y[i])

# %%
len(clock)# OF ACCIDENTS

# %%
len(CLOCK)# OF ACCIDENTS+ # OF INCIDENTS

# %%
final=[]
for key, value in CLOCK.items():
    if key in clock:
        ratio=clock[key]/CLOCK[key]
        temp=(key, ratio)
        final.append(temp)
    else:
        temp=(key, 0)
        final.append(temp)

# %%
final[110]
#clock[79] , CLOCK[79]

# %% [markdown]
# # # OF ACCIDENTS : (# OF ACCIDENTS+ # OF INCIDENTS)

# %%
_y=y.iloc[:,0].values
_y.shape
y.head()

# %% [markdown]
# # Classification

# %%
x.dtypes

# %% [markdown]
# #
# OccID : unique ID
# AircraftTypeID :
# AircraftMakeID :
# OrganizationID :
# OperationTypeID :
# OperatorTypeID :
# WeightCategoryID :
# YearOfManuf :
# NumberOfEngine :
# MaxTakeOffWeight :
# NumberOfEngine :
# OccDate :
# OccTime :
# Latitude :
# Longitude :
# DamageLevelID :
# WakeTurbulenceCategoryID :
# DangerousGoodEnum :
# PhaseID :
# TotalFatalCount :

# %%
x.OrganizationID=x.OrganizationID.astype("int64")

# %%
label_encoder=LabelEncoder()
x["OrganizationID"]=label_encoder.fit_transform(x["OrganizationID"])

# %%
x.OrganizationID

# %%
# dfa.drop_duplicates(subset ="OccID", 
#                      keep = False, inplace = True) 
# #df.dropna(inplace = True)

# %% [markdown]
# ### Classify using RFC

# %%
#Using knqk's preprocessing

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=6)

# %%
model = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0).fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)
print(y_pred)

# %%
y_test

# %%
model.score(x_test, y_test)

# %% [markdown]
# # Clustering

# %%
from sklearn import neighbors
from sklearn.cluster import KMeans

# %%
X_=x
sum_square = {}

for k in range(1, 20):
    kmeans_aviation = KMeans(n_clusters = k).fit(X_)
    sum_square[k] = kmeans_aviation.inertia_
print(X_.shape)
print(X_.columns)
print(X_.head)

# %%
X_.head()

# %%
plt.plot(list(sum_square.keys()), list(sum_square.values()),
         linestyle ='-', marker = 'o', color = 'b',
         markersize = 8,markerfacecolor = 'r')

# %% [markdown]
# ### Clustering with 5 centers

# %%
kmeans_5 = KMeans(n_clusters=5, random_state=0).fit(X_)
print('Cluster model K=5 inertia score is: ', kmeans_5.inertia_)
y=kmeans_5.predict(X_)

# %%
centers5 = kmeans_5.cluster_centers_
centers5

# %%
X_['klabels_5'] = kmeans_5.labels_

# %%
df.columns

# %%
X_.head()
#X_.shape

# %%
# Y=dfa["OccTypeID"]
# y is your prediction
# compare y and Y in the metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(df['OccTypeID'], kmeans_5.labels_))

# %%
X_.klabels_5.value_counts()

# %%
df.OccTypeID.value_counts()

# %% [markdown]
# ### Clustering with 4 centers

# %%
kmeans_4 = KMeans(n_clusters=4, random_state=0).fit(X_)
print('Cluster model K=4 inertia score is: ', kmeans_4.inertia_)
y=kmeans_4.predict(X_)

# %%
centers4 = kmeans_4.cluster_centers_
centers4

# %%
X_['klabels_4'] = kmeans_4.labels_

# %%
df.columns

# %%
X_.head()
#X_.shape

# %%
# Y=dfa["OccTypeID"]
# y is your prediction
# compare y and Y in the metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(df['OccTypeID'], kmeans_4.labels_))

# %%
print(confusion_matrix(df['OccTypeID'], kmeans_4.labels_))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(df.OccTypeID, kmeans_4.labels_)

# %%
X_.klabels_4.value_counts()

# %%
df.OccTypeID.value_counts()

# %%
f, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2,
                             sharey = True, figsize = (10,6))

# For fitted with kmeans 
ax1.set_title('K Means (K = 4)')
ax1.scatter(x = X_['MaxTakeOffWeight'], y = X_['OccTime'], 
            c = X_['klabels_4'], cmap='rainbow')
ax1.scatter(x=centers4[:, 7], y=centers4[:, 5],
            c='black',s=300, alpha=0.5);

# For original data 
ax2.set_title("Original")
ax2.scatter(x = dfm['AircraftMakeID'], y = dfm['OccTime'], 
            c = dfm['OccTypeID'], cmap='rainbow')

# %% [markdown]
# ### Clustering with 3 centers

# %%
kmeans_3 = KMeans(n_clusters=3, random_state=0).fit(X_)
print('Cluster model K=4 inertia score is: ', kmeans_3.inertia_)
y=kmeans_3.predict(X_)

# %%
centers3 = kmeans_3.cluster_centers_
centers3

# %%
X_['klabels_3'] = kmeans_3.labels_

# %%
df.columns

# %%
X_.head()
#X_.shape

# %%
# Y=dfa["OccTypeID"]
# y is your prediction
# compare y and Y in the metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(df['OccTypeID'], kmeans_3.labels_))

# %%
print(confusion_matrix(df['OccTypeID'], kmeans_3.labels_))

# %%
X_.klabels_3.value_counts()

# %%
df.OccTypeID.value_counts()
